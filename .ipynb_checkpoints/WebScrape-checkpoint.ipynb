# %%
import certifi
import urllib3
from bs4 import BeautifulSoup as bs
import pprint as pp
import os
from multiprocessing import Pool
import json
from numpy.random import choice

# %% [markdown]
# # Web scraping

# %%
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())

# %%
# define paths for data caching
dataDir = 'data'
if not os.path.exists(dataDir):
    os.makedirs(dataDir)
urlListFName = '%s/urls.txt' % dataDir

# %% [markdown]
# ## wineoneline.com.au

# %%
# initialise web fetching stuff
domain = "http://www.wineonline.com.au"
dataDirThisDomain = dataDir + '/wineonline'
woAllTextFname = '%s/all.txt' % dataDirThisDomain

# %%
# scrape list of wines to get a list of urls to individual wines
if not os.path.exists(urlListFName):
    individualPages = []

    # get list of wine pages
    for wine_type in ['sparkling','white-wine','red-wine','imported']:
        print("Start of wine_type %s" % wine_type)
        page = 0
        while True:
            suffix = '?sort=alphaasc&page=%d' % page
            url = '/'.join([domain,wine_type,suffix])
            r = http.request('GET',url)
            if r.status == 200:
                print("Hit: " + url)
                html = r.data.decode('utf-8')
                soup = bs(html, 'html.parser')
                individualPages += [a.get('href') for a in soup.select('.ProdHeading a')]
                page = page + 1

            else:
                print("end of %s at %d" % (wine_type, page))
                break
    individualPages = list(set(individualPages))
    print("Writing list of urls to %s" % urlListFName)
    with open(urlListFName,'w') as f:
        f.write('\n'.join(individualPages))
else:
    print("Skipping fetching from the search results pages")
print("Reading in from %s" % urlListFName)
with open(urlListFName,'r') as f:
    individualPages = [line.strip() for line in f.read().split('\n') if line.strip() != '']
#individualPages = individualPages[:10] # only some for now
print("done")
# Out:
# Skipping fetching from the search results pages
# Reading in from data/urls.txt
# done

# %%
paths = [url.rstrip('/').split('/')[-1] for url in individualPages]
assert(len(paths) == len(individualPages))
print("done")
# Out:
# done

# %%
# scrape all the wines in the list

def fetchPath(path):
#     print("fetching %s" % url)
    url = domain.rstrip('/') + '/' + path.lstrip('/')
    dirName = '%s/bottles/%s' % (dataDirThisDomain,path)
    if not os.path.exists(dirName):
        os.makedirs(dirName)
    htmlFName = '%s/%s' % (dirName,'html.html')
    if not os.path.exists(htmlFName):
        print("Fetching %s" % url)
        r = http.request('GET',url)
        if r.status == 200:
    #         print("Parsing %s" % url)
            html = r.data.decode('utf-8').replace(u'\xa0', u' ')
            print("Saving to %s" % htmlFName)
            with open(htmlFName,'w') as f:
                f.write(html)
        else:
            print("Error, status %d for url %s" % (r.status,url))
            return([])
    else:
        print("Hit cache for %s" % htmlFName)
    with open(htmlFName,'r') as f:
        html = f.read()
    return(html)
    

if not os.path.exists(woAllTextFname):
    with Pool(20) as p:
        htmls = p.map(fetchPath,paths)
    print("done")
else:
    print("Skipping, because I'll read from cache")
# Out:
# Skipping, because I'll read from cache

# %%
if not os.path.exists(woAllTextFname):
    paras = []
    soups = [bs(html) for html in htmls]
    for soup in soups:
        print('next soup')
        paras += soup.select('#ProductDescription p')

    print("done")
else:
    print("Skipping, because I'll read from cache")
# Out:
# Skipping, because I'll read from cache

# %%
if not os.path.exists(woAllTextFname):
    for para in paras:
        for tag in ['span','strong','p']:
            for el in para.find_all(tag):
                if el.string:
                    num_words = len(el.string.replace('\n',' ').split(' '))
                    if num_words < 15:
                        el.string.replace_with('')
else:
    print("Skipping, because I'll read from cache")
# Out:
# Skipping, because I'll read from cache

# %%
if not os.path.exists(woAllTextFname):
    text = '\n'.join([para.get_text() for para in paras]).replace(u'\xa0',' ')
    for c in '.?!':
        text = text.replace(c,c + ' ').replace(c + '  ',c + ' ')
    with open(woAllTextFname,'w') as f:
        f.write(text)

with open(woAllTextFname,'r') as f:
    allTextWO = f.read()

# %% [markdown]
# ## nakedwines.com.au

# %%
# found the number 210 through trial and error
# bigger number means more results per page
# but their crappy site fails when you enter a number too big (e.g. 210)
domain = 'https://www.nakedwines.com.au'

dataDirThisDomain = dataDir + '/nakedwines'

# %%
def getSearchResults(searchPage):
    url = domain + "/wines/index?searchText=&sortWines=descprice&pageSize=20&view=Wines&layoutType=card&allWines=true&pageNum=%d" % searchPage
    print("Fetching " + url)
    r = http.request('GET',url)
    assert(r.status == 200)
    print("Hit: " + url)
    html = r.data.decode('utf-8')
    soup = bs(html, 'html.parser')
    links = [a.get('href') for a in soup.select('a.card__header')]
    print("Found %d results for searchPage %d" % (len(links),searchPage))
    return(links)



if not os.path.exists(dataDirThisDomain):
    os.makedirs(dataDirThisDomain)
fname = '%s/paths.txt' % dataDirThisDomain

if not os.path.exists(fname):
    print("No cache found, fetching from search results on " + domain)
    searchPage = 0
    results = getSearchResults(searchPage)
    individualPages = results
    while len(results) > 0:
        searchPage += 1
        results = getSearchResults(searchPage)
        individualPages += results
    with open(fname,'w') as f:
        f.write('\n'.join(individualPages))
    # write and then read back from file
    # to make sure we wrote correctly

print("Reading urls from cache")
with open(fname,'r') as f:
    individualPages = [x.strip() for x in f.read().split('\n') if x.strip() != '']
    

print("Using urls:")
print('\n'.join(individualPages[:3] + ['...'])) 
print("Discovered %d individual pages" % len(individualPages))
# Out:
# Reading urls from cache
# Using urls:
# /products/karriview-pinot-noir-2016
# /products/sorby-adams-small-barrel-barossa-shiraz-2016
# /products/sam-plunkett-single-vineyard-series-gentle-annie-shiraz-2017
# ...
# Discovered 306 individual pages

# %%
def fetchPath(path):
    url = domain + path
    print("Fetching " + url)
    r = http.request('GET',url)
    assert(r.status == 200)
    print("Hit: " + url)
    html = r.data.decode('utf-8')
    fname = dataDirThisDomain.rstrip('/') + '/' + path.lstrip('/') + '.html'
    directory = '/'.join(fname.split('/')[:-1])
    if not os.path.exists(directory):
        os.makedirs(directory)
    with open(fname,'w') as f:
        f.write(html)
    soup = bs(html, 'html.parser')
    textEls = soup.find(id="tab-tick")
    assert(textEls)
    text = textEls.get_text().replace(u'\xa0',' ').strip()
    for c in '.?!':
        text = text.replace(c,c + ' ').replace(c + '  ',c + ' ')
    return(text)

fname = '%s/all.txt' % dataDirThisDomain 
if not os.path.exists(fname):
    print("No cache, fetching")
    with Pool(20) as p:
        texts = p.map(fetchPath,individualPages)
    with open(fname,'w') as f:
        f.write('\n'.join(texts))
else:
    print("hit cache")
    
with open(fname,'r') as f:
    allTextNW = f.read()

    
print("done")
# Out:
# hit cache
# done

# %% [markdown]
# ## combining web scrapes

# %%
allText = allTextWO + '\n' + allTextNW

# %%
# takes in a string, returns an array of words
# where punctuation is a 'word'
def toWords(s):
    s = s.replace('\n',' ')
    s = s.replace('\t',' ')
    words = []
    for chunk in s.split(' '):
        chunk = chunk.lstrip('([{\'').rstrip(')]}').strip('`‘""')
        if chunk.strip() != '':
            punctuation = ',.?!;'
            for p in punctuation:
                if chunk.endswith(p):
                    words.append(chunk[:-1])
                    words.append(p)
            if not(any([chunk.endswith(p) for p in punctuation])):
                words.append(chunk)
              
    wordsS = set(words)
    func = lambda x: x.lower() if x.lower() in wordsS else x
    words = [func(w) for w in words]
    return(words)

def testToWords():
    s = 'At the dawn'
    words = ['At','the','dawn']
    assert(words==toWords(s))
    
    s = 'Of a  new  age\n'
    words = ['Of','a','new','age']
    assert(words==toWords(s))
    
    s = 'At the dawn, of  a\nnew \n age!'
    expected = ['At','the','dawn',',','of','a','new','age','!']
    actual = toWords(s)
    if expected != actual:
        print("expected: ")
        pp.pprint(expected)
        print("actual: ")
        pp.pprint(actual)
    assert(expected==actual)
    
    s = 'Here is here'
    words = ['here','is','here']
    assert(words==toWords(s))
    
    s = 'Here is (bracket stuff)'
    words = ['Here','is','bracket','stuff']
    if words != toWords(s):
        print(toWords(s))
    assert(words==toWords(s))
    
    s = 'Here is "a quote"'
    words = ['Here','is','a','quote']
    assert(words==toWords(s))
    
    s = "Ha! That's funny"
    words = ['Ha','!',"That's",'funny']
    assert(words==toWords(s))
    
testToWords()
print("test passed")
# Out:
# test passed

# %%
allTextSplit = toWords(allText)
print(allTextSplit)
# Out:
# ['is', 'one', 'of', 'elegance', 'and', 'finesse', ',', 'displaying', 'notations', 'of', 'citrus', 'sorbet', ',', 'green', 'apple', 'and', 'yeast', ',', 'amidst', 'a', 'creamy', ',', 'finely', 'beaded', 'body', '.', 'Bountiful', 'aromatics', 'ascend', '–', 'initially', 'redcurrant', ',', 'cranberry', ',', 'Christmas', 'cake', 'mix', ',', 'and', 'then', 'the', 'liberation', 'of', 'citrus', 'lime', 'peel)', ',', 'fennel', 'and', 'olive', '.', 'middle', 'eastern', 'spices', 'also', 'present', '–', 'sweet', ',', 'not', 'savoury', 'incl', '.', 'cinnamon', ',', 'nutmeg)', '.', 'and', ',', 'not', 'unexpected', ',', 'something', 'not', 'present', '-', 'oak', '!', 'to', 'please', 'all', 'tastes', '-', 'the', 'sweet', '–', 'zabaglione', ',', 'custard', ',', 'raw', 'chocolate', 'cocoa)', ';', 'and', 'the', 'savoury', '–', 'bone', 'marrow', ',', 'star', 'anise', '.', 'lingers', ',', 'and', 'certainly', 'leaves', 'a', 'most', 'appealing', 'residual’', 'impression', 'for', 'quite', 'some', 'time', 'after', 'ingestion', '.', 'Geoff', 'Merrill', 'Wickham', 'park', 'chardonnay', '2010', 'is', 'pale', 'straw', 'in', 'colour', 'with', 'youthful', 'green', 'hues', '.', 'aromas', 'of', 'citrus', ',', 'nectarine', 'and', 'melon', ',', 'followed', 'by', 'hints', 'of', 'toasted', 'oak', '.', 'the', 'palate', 'offers', 'notes', 'of', 'fresh', 'fruit', 'with', 'a', 'creamy', 'finish', '.', 'Louis', 'Roederer', 'brut', 'premier', 'NV', 'is', 'a', 'pale', 'golden', 'yellow', 'colour', 'with', 'delicate', 'persistent', 'beads', '.', 'this', 'champagne', 'displays', 'aromas', 'of', 'acacia', ',', 'almonds', 'and', 'toast', '.', 'the', 'palate', 'displays', 'a', 'wonderful', 'complexity', 'and', 'roundness', 'with', 'honeyed', 'richness', ',', 'butterscotch', ',', 'brioche', 'and', 'cinnamon', ',', 'finessed', 'with', 'a', 'cut', 'of', 'lemon', '.', 'works', 'well', 'with', 'shellfish', 'lobster)', ',', 'fois', 'gras', ',', 'natural', 'oysters', 'and', 'sushi/sashimi', 'plus', 'white', 'fish', 'and', 'poultry', 'dishes', '.', 'Shadowfax', 'single', 'vineyard', 'Geelong', 'Semillon', '2010', 'is', 'pale', 'straw', 'green', 'in', 'colour', '.', 'bouquet', 'of', 'talc', ',', 'straw', ',', 'a', 'hint', 'of', 'snow', 'pea', 'and', 'almond', 'kernel', '.', 'very', 'fresh', ',', 'focused', 'and', 'bright', 'palate', 'with', 'hints', 'of', 'lemon', 'zest', 'and', 'fennel', '.', 'this', 'Semillon', 'is', 'bone', 'dry', ',', 'with', 'fine', 'extract', 'adding', 'to', 'the', 'length', '.', 'seamless', 'and', 'clean', ',', "it's", 'an', 'alternative', 'take', 'of', 'the', 'classic', 'Australian', 'Hunter', 'valley', 'style', 'of', 'Semillon', '.', 'matches', 'well', 'with', 'green', 'salad', ',', 'fresh', 'asparagus', 'and', 'scallops', '.', 'aroon', 'in', 'colour', 'with', 'a', 'red', 'brick', 'hue', '.', 'a', 'tightly', 'woven', ',', 'complex', 'and', 'elegant', 'nose', 'with', 'prominent', 'notes', 'of', 'red', 'berries', ',', 'and', 'blackcurrant', 'intertwined', 'with', 'hints', 'of', 'licorice', ',', 'dried', 'leaf', ',', 'tomato', 'bush', ',', 'cedar', 'and', 'smoky', 'oak', 'spice', '.', 'Arrives', 'savoury', ',', 'yet', 'fruit', 'filled', ',', 'with', 'succulent', 'and', 'luscious', 'blackcurrant', 'and', 'red', 'berry', 'and', 'bright', 'acidity', '.', 'it', 'builds', 'with', 'wonderful', 'stony', ',', 'but', 'sinewy', ',', 'fine', 'tannins', 'and', 'finishes', 'with', 'intriguing', 'earth', 'notes', 'of', 'native', 'dried', 'twigs', '.', 'Jim', 'Beam', 'black', 'label', 'Bourbon', '700ml', 'offers', 'an', 'intense', 'and', 'complex', 'experience', '.', 'this', 'Bourbon', 'is', 'triple', 'aged', 'for', '6', 'years', ';', 'this', 'aging', 'process', 'gives', 'the', 'Bourbon', 'an', 'extra', 'full', 'flavoured', 'palate', 'with', 'notes', 'of', 'winter', 'spice', 'including', 'nutmeg', 'and', 'cinnamon', '.', 'Hewitson', "Basham's", 'Beach', 'Tempranillo', '2012', 'offers', 'flavours', 'of', 'blackberry', 'and', 'coffee', 'ground', 'followed', 'by', 'spice', 'an ...

# %% [markdown]
# # Single Layer Chain

# %%
dataOne = {}
for i in range(1,len(allTextSplit)):
    if (i % 10000) == 0:
        print('...')
    thisWord = allTextSplit[i]
    prevWord = allTextSplit[i-1]
    if prevWord == '.':
        prevWord = '' # use empty string to represent start
    if prevWord not in dataOne:
        dataOne[prevWord] = {thisWord:1}
    elif thisWord in dataOne[prevWord]:
        dataOne[prevWord][thisWord] += 1
    else:
        dataOne[prevWord][thisWord] = 1
        
# remove single character sentences
for c in '?!.;':
    if c in dataOne['']:
        del dataOne[''][c]
print("done")
dataOne
# Out:
# ...
# ...
# ...
# ...
# ...
# ...
# done
# {'is': {'one': 15,
#   'pale': 19,
#   'a': 179,
#   'bone': 1,
#   'triple': 2,
#   'full-bodied': 8,
#   'rich': 14,
#   'perfect': 6,
#   'vibrant': 9,
#   'silky': 4,
#   'plenty': 1,
#   'intense': 3,
#   'ripe': 2,
#   'complex': 3,
#   'deep': 18,
#   'lifted': 1,
#   'mouth': 1,
#   'bright': 12,
#   'typically': 3,
#   'well-concentrated': 1,
#   'very': 12,
#   'fresh': 12,
#   'well': 9,
#   'supple': 1,
#   'endless': 1,
#   'produced': 4,
#   'balanced': 4,
#   'opaque': 3,
#   'ideal': 1,
#   'light': 5,
#   'salmon': 1,
#   'just': 4,
#   'full': 9,
#   'pale-straw': 1,
#   'the': 72,
#   'quintessentially': 1,
#   'capable': 1,
#   'yellow': 1,
#   'known': 6,
#   'aged': 1,
#   'undoubtedly': 3,
#   'characterised': 1,
#   'stray': 1,
#   'displaying': 1,
#   'breathtakingly': 1,
#   'its': 1,
#   'alive': 1,
#   'name': 1,
#   'held': 1,
#   'today': 1,
#   'distilled': 1,
#   'straw': 2,
#   'completely': 1,
#   'fleshy': 2,
#   'long': 5,
#   'sourced': 14,
#   'used': 4,
#   '100%': 4,
#   'gone': 2,
#   'complemented': 3,
#   'made': 14,
#   ',': 2,
#   'this': 3,
#   'more': 4,
#   'not': 9,
#   'crammed': 2,
#   'subtle': 1,
#   'layered': 1,
#   'primal': 1,
#   'achieved': 1,
#   'medium': 15,
#   'persistent': 1,
#   'effortlessly': 1,
#   'elegant': 3,
#   'fruity': 2,
#   'exceptional': 1,
#   'magenta': 1,
#   'youthful': 1,
#   'intrinsically': 1,
#   'now': 1,
#   'an': 25,
#   'exceptionally': 1,
#   'medium-full': 1,
#   'finely': 4,
#   'tightly': 1,
#   'located': 3,
#   'often': 3,
#   'further': 1,
#   'generous': 3,
#   'fermented': 1,
#   'amply': 1,
#   'reserved': 1,
#   'always': 2,
#   'given': 2,
#   'soft': 11,
#   'becoming': 1,
#   'tipped': 1,
#   'plush': 1,
#   'quite': 7,
#   'lively': 4,
#   'rounded': 1,
#   'enhanced': 2,
#   'therefore': 1,
#   'sure': 17,
#   'nicely': 1,
#   'secondary': 1,
#   'packed': 8,
#   'incidental': 1,
#   'bursting': 1,
#   'matched': 1,
#   'refreshing': 6,
#   'followed': 1,
#   'simultaneously': 1,
#   'edgy': 1,
#   'dark': 1,
#   'quoted': 1,
#   'delicate': 2,
#   'compact': 1,
#   'primarily': 1,
#   'matured': 2,
#   'crisp': 5,
#   'such': 2,
#   'still': 1,
#   'displays': 1,
#   'visible': 1,
#   'tender': 1,
#   'all': 7,
#   'during': 1,
#   'dependent': 1,
#   'stored': 1,
#   'sweet': 1,
#   'also': 7,
#   'blended': 2,
#   'big': 1,
#   'filled': 1,
#   'jam': 1,
#   'home': 1,
#   'fine': 2,
#   'perfumed': 4,
#   'smooth': 3,
#   'joyous': 1,
#   'purple': 1,
#   'named': 1,
#   'clearly': 1,
#   'awash': 1,
#   'incredibly': 1,
#   'meticulously': 1,
#   'on': 5,
#   'medium-bodied': 2,
#   'slightly': 2,
#   'refined': 4,
#   'precise': 1,
#   'savoury': 1,
#   'crimson': 1,
#   'modelled': 1,
#   'off-set': 1,
#   'classic': 1,
#   'dry': 1,
#   'associated': 1,
#   'little': 1,
#   'something': 3,
#   'brooding': 1,
#   'exactly': 1,
#   'no': 14,
#   'widely': 1,
#   'bold': 2,
#   'definitely': 3,
#   'pinot': 1,
#   'renowned': 6,
#   'our': 1,
#   'concerned': 1,
#   'their': 3,
#   'modern': 2,
#   'truly': 9,
#   'certainly': 7,
#   'near': 1,
#   'almost': 4,
#   'amazing': 2,
#   'consistently': 2,
#   'where': 1,
#   'like': 1,
#   'about': 7,
#   'developing': 1,
#   'so': 4,
#   'in': 6,
#   'pure': 1,
#   'inspired': 4,
#   'simply': 1,
#   'paramount': 1,
#   'sexy': 1,
#   'robust': 1,
#   'met': 1,
#   'underwritten': 1,
#   'certain': 1,
#   'going': 1,
#   'certified': 1,
#   'crafted': 5,
#   'around': 1,
#   'her': 2,
#   'when': 1,
#   'naturally': 1,
#   'vital': 1,
#   'thanks': 1,
#   'here': 5,
#   'guaranteed': 3,
#   'remote': 1,
#   'too': 3,
#   'exclusive': 2,
#   'back': 18,
#   'hands': 1,
#   'beautifully': 1,
#   'multi-layered': 1,
#   'fast': 3,
#   'bound': 1,
#   'topped': 1,
#   'next': 1,
#   '.': 1,
#   'likely': 1,
#   'as': 2,
#   'all-too': 1,
#   'reflected': 1,
#   'at': 1,
#   'coupled': 1,
#   'pretty': 3,
#   'evident': 4,
#   'silky-soft': 1,
#   'famous': 2,
#   'combined': 2,
#   '-': 2,
#   'again"': 2,
#   'for': 3,
#   'off': 1,
#   'overflowing': 1,
#   'comprised': 1,
#   'suited': 1,
#   'brimming': 3,
#   'quickly': 1,
#   'charming': 1,
#   'situated': 3,
#   'over': 1,
#   'dosed': 1,
#   'probably': 2,
#   'savvy': 2,
#   'hard': 2,
#   'even': 2,
#   'widespread': 1,
#   'much': 1,
#   'stupendous': 1,
#   'totally': 1,
#   'own': 2,
#   'practically': 1,
#   'fortified': 1,
#   'stunning': 1,
#   '10': 1,
#   'seriously': 1,
#   'infectious': 1,
#   "Leighton's": 1,
#   'reflective': 1,
#   'downright': 1,
#   'textural': 2,
#   'only': 2,
#   'refreshingly': 1,
#   'heightened': 1,
#   'tied': 1,
#   'inherent': 1,
#   'your': 5,
#   'posied': 1,
#   'fruit': 1,
#   'sooo': 3,
#   'softly': 2,
#   'has': 1,
#   'unreal': 1,
#   'proud': 2,
#   'among': 1,
#   'powerful': 1,
#   'Judy': 2,
#   'what': 2,
#   'finding': 2,
#   'considered': 2,
#   'lovely': 1,
#   'Angel': 1,
#   'deliciously': 4,
#   'styled': 1,
#   'commonly': 1,
#   'Ben': 1,
#   'cool': 1,
#   'able': 1,
#   'super': 1,
#   'second': 1,
#   'oozing': 1,
#   'mind-blowing': 1,
#   'through': 1,
#   'from': 1,
#   'seamlessly': 1,
#   'great': 2,
#   'low': 1,
#   'greater': 2,
#   'Stuart’s': 1,
#   'easy': 1,
#   'incredible': 1,
#   'out': 1,
#   'exclusively': 1,
#   'utterly': 1,
#   'another': 1,
#   'Adam': 1,
#   "Jock's": 1,
#   'food': 1,
#   'relatively': 1,
#   'already': 1,
#   'responsible': 5,
#   'mostly': 2,
#   'drinking': 2,
#   'Geoff': 1,
#   'thrilled': 1,
#   'making': 1,
#   'packaged': 1,
#   'world': 1,
#   'punching': 1,
#   'zesty': 1,
#   'quality': 1,
#   'soaked': 1,
#   'cold-fermented': 1,
#   'looking': 1,
#   'teamed': 1,
#   'perfectly': 1,
#   'challenging': 1,
#   'delicious': 2,
#   'gives': 1,
#   'wine': 1,
#   "Jen's": 1,
#   'delightful': 2,
#   'tough': 1},
#  'one': {'of': 54,
#   'bottle': 1,
#   'year': 3,
#   'day…around': 1,
#   'delicious': 2,
#   'to': 5,
#   'and': 5,
#   'won’t': 1,
#   'region': 1,
#   'sip': 3,
#   '!': 1,
#   'full': 1,
#   'which': 1,
#   'that': 1,
#   'more': 3,
#   'shows': 2,
#   'steeped': 1,
#   'ready': 1,
#   'day': 2,
#   "more'": 2,
#   'boutique': 1,
#   'for': 4,
#   'taste': 1},
#  'of': {'elegance': 1,
#   'citrus': 21,
#   'toasted': 2,
#   'fresh': 30,
#   'acacia': 1,
#   'lemon': 6,
#   'talc': 1,
#   'snow': 1,
#   'the': 246,
#   'Semillon': 6,
#   'red': 30,
#   'licorice': 3,
#   'native': 1,
#   'winter': 1,
#   'blackberry': 10,
#   'brioche': 2,
#   'sweet': 19,
#   'pear': 13,
#   'even': 2,
#   'pinot': 12,
#   "Australia's": 5,
#   '35': 1,
#   'spice': 13,
#   'pawpaw': 1,
#   'tea': 1,
#   'luxe': 1,
#   'toast': 3,
#   'flavour': 40,
#   'vanilla': 7,
#   'dark': 33,
#   'five': 2,
#   'soot/coal': 2,
#   'nectarine': 3,
#   'grapefruit': 7,
#   'satsuma': 2,
#   'assorted': 1,
#   'fruits': 2,
#   'tiramisu': 1,
#   'white': 18,
#   'rosewater': 2,
#   'paw-paw': 1,
#   'foods': 1,
#   'lime': 5,
#   'lychee': 2,
#   'both': 9,
#   'oak': 15,
#   'chocolate': 5,
#   'this': 78,
#   'mocha/coffee': 1,
#   'pepper': 3,
#   'lamb': 2,
#   'London': 1,
#   'anise': 3,
#   'black': 17,
#   'ripe': 20,
#   'liquorice': 3,
#   'Western': 3,
#   'mulberry': 6,
#   'honey': 2,
#   'wild': 7,
#   'apricot': 3,
#   'south': 11,
#   'aromas': 6,
#   'cashew': 5,
#   'nutmeg': 3,
#   'whom': 1,
#   'Johann': 1,
#   'their': 13,
#   'those': 2,
#   'heat': 2,
#   'April': 1,
#   'guava': 3,
#   'sweetness': 1,
#   'Whitehaven': 1,
#   'freshly': 3,
#   'developing': 1,
#   'Scarpantoni': 1,
#   'where': 1,
#   'gold': 2,
#   'fine': 4,
#   'almond': 2,
#   'violets': 5,
#   'redcurrants': 1,
#   'green': 7,
#   'plum': 11,
#   'pure': 2,
#   'coriander': 1,
#   'pineapple': 5,
#   'bread-crust': 1,
#   'cantaloupe': 1,
#   'complex': 1,
#   'orange': 11,
#   'youthful': 1,
#   '11': 1,
#   'love': 9,
#   'berry': 7,
#   'smoky/toasty': 1,
#   'mushroom': 1,
#   'great': 3,
#   'la': 2,
#   '1998': 1,
#   'mixed': 2,
#   'heavier': 1,
#   'very': 4,
#   '28': 1,
#   'peach': 7,
#   'cranberry': 2,
#   'friends': 1,
#   'course': 4,
#   'apple': 9,
#   'occasions': 1,
#   'savoury': 7,
#   'floral': 4,
#   'caramelised': 1,
#   'musk': 3,
#   'jasmine': 4,
#   'cumquat': 1,
#   'quality': 9,
#   'viticulture': 1,
#   'all': 7,
#   'which': 2,
#   'Renmark': 1,
#   'post': 1,
#   'flowers': 1,
#   'wine': 13,
#   'gas': 1,
#   'crushed': 1,
#   'passionfruit': 8,
#   'wood': 2,
#   'barrel': 6,
#   'substance': 3,
#   'nougat': 3,
#   'stonefruits': 1,
#   'cracked': 1,
#   'shiraz': 13,
#   'cherry': 11,
#   'rotary': 1,
#   'a': 33,
#   'raspberry': 11,
#   'nature': 1,
#   'different': 3,
#   '2010-2011': 1,
#   'turkish': 3,
#   'its': 9,
#   '2011': 1,
#   'dried': 5,
#   'fruit': 46,
#   'smoked': 1,
#   'making': 3,
#   'grigio': 1,
#   'cinnamon': 5,
#   'stone': 9,
#   'fullness': 1,
#   'classic': 2,
#   'nuts': 2,
#   'bright': 4,
#   'soy': 2,
#   'kirsch': 2,
#   'open': 1,
#   'flavours': 10,
#   'purity': 1,
#   'exceptional': 3,
#   'intense': 5,
#   '36': 1,
#   'Australian': 4,
#   'Coonawarra’s': 1,
#   'grapes': 7,
#   'outstanding': 1,
#   'Prodigy': 1,
#   'rich': 4,
#   'strawberry': 6,
#   'ristretto': 2,
#   'glazed': 2,
#   'tannin': 2,
#   'grilled': 2,
#   'cassis': 2,
#   'boysenberry': 1,
#   'Bordeaux': 3,
#   'tannins': 1,
#   'fig': 2,
#   'freshly-cured': 1,
#   'pickled': 1,
#   'french': 7,
#   'elegant': 1,
#   'natural': 3,
#   'sweet-fruit': 1,
#   'bold': 1,
#   'American': 1,
#   'mint': 5,
#   'blackcurrant': 13,
#   'minty': 1,
#   'Coonawarra': 3,
#   'new': 7,
#   '2009': 1,
#   'Grande': 1,
#   'grainy': 1,
#   'ten': 1,
#   'high': 3,
#   'previous': 1,
#   'rain': 3,
#   '23': 1,
#   'pressing': 1,
#   'fermentation': 1,
#   'plums': 2,
#   'complexity': 9,
#   'single': 1,
#   'smokey': 1,
#   'clove': 1,
#   'yeast': 1,
#   'older': 2,
#   'tropical': 7,
#   'indigenous': 1,
#   'acid': 2,
#   'such': 2,
#   'stress': 1,
#   'syrah': 1,
#   '60%': 1,
#   'ferment': 1,
#   'maceration': 1,
#   'Victoria': 3,
#   'Ponds': 1,
#   'lifted': 6,
#   'cured': 2,
#   'raspberries': 2,
#   'smoky': 1,
#   'length': 2,
#   'power': 1,
#   'wines': 2,
#   'cabernet': 8,
#   'char': 1,
#   'honeysuckle': 2,
#   'our': 1,
#   'traditional': 1,
#   'roses': 1,
#   'wet': 1,
#   'at': 1,
#   'hours': 1,
#   'delicate': 2,
#   'Tasmania': 3,
#   'aged': 1,
#   'Fires': 3,
#   'classical': 1,
#   'life': 4,
#   'spiced': 1,
#   'blueberry': 3,
#   'cookies': 1,
#   'nut': 1,
#   'soft': 4,
#   'spicy': 5,
#   'elevated': 1,
#   'hot': 1,
#   'Toddlers': 1,
#   'energy': 2,
#   'mulberries': 3,
#   'bitter': 1,
#   'berries': 1,
#   'juicy': 13,
#   'melon': 2,
#   'SO2': 1,
#   'steep': 1,
#   'ripening': 3,
#   'consistent': 1,
#   'Dom': 1,
#   'aromatic': 2,
#   'practice': 1,
#   'sour': 1,
#   'redcurrant': 2,
#   'cool-climate': 1,
#   'Bin': 1,
#   'line': 1,
#   'lobster': 1,
#   'plump': 2,
#   "baker's": 1,
#   'crispy': 1,
#   'rhubarb': 1,
#   'rose': 5,
#   'Arras': 3,
#   'premium': 3,
#   'character': 4,
#   'world': 1,
#   'exotic': 2,
#   'chardonnay': 8,
#   'lees': 1,
#   'sun-dried': 1,
#   'toffee': 1,
#   'from': 1,
#   'France': 3,
#   '69': 1,
#   'heady': 1,
#   'pomegranate': 1,
#   'aging': 1,
#   'yellow': 1,
#   ',': 3,
#   'malbec': 2,
#   'choc': 1,
#   'interesting': 1,
#   'leather': 1,
#   'three': 4,
#   'raspberry/cranberry': 1,
#   'cold': 1,
#   'January': 1,
#   'veraison': 1,
#   'pristine': 1,
#   'Penfolds': 1,
#   'fruitcake': 1,
#   'creamy': 3,
#   'mineral': 1,
#   'magnificence': 1,
#   'tangy': 1,
#   'earthiness': 2,
#   'duck': 1,
#   'Christmas': 1,
#   'flint': 4,
#   'acidity': 3,
#   'peppercorn': 1,
#   'hazelnut': 2,
#   'vividness': 1,
#   'time': 1,
#   'rosemary': 1,
#   'old': 1,
#   'subtle': 5,
#   'early': 2,
#   'superb': 1,
#   'nashi': 1,
#   'charry': 1,
#   'it': 2,
#   'smelling': 1,
#   'charm': 1,
#   'enticing': 1,
#   'concentrated': 1,
#   'minerality': 3,
#   'cedary': 1,
#   'gooseberry': 2,
#   'menthol': 1,
#   'boiled': 1,
#   'fuzzy': 1,
#   'aromatics': 1,
#   'eucalyptus': 1,
#   'confectionary': 1,
#   'quince': 1,
#   'toasty': 3,
#   'optimum': 1,
#   'intrigue': 1,
#   'WA': 2,
#   'mocha': 3,
#   'maturation': 3,
#   'nuance': 1,
#   'generosity': 1,
#   'intensly': 1,
#   'velvet': 1,
#   'what': 3,
#   'deliciousness': 3,
#   'Heathcote': 2,
#   "Tait's": 1,
#   "Naked's": 2,
#   'nutty': 1,
#   'his': 16,
#   'local': 2,
#   'Aussie': 1,
#   'Sicily': 1,
#   'Gypsy': 2,
#   'your': 13,
#   'big': 1,
#   'residual': 2,
#   'Burgundy': 1,
#   'passion': 3,
#   'Douro': 1,
#   'port': 1,
#   'years': 3,
#   'herbs': 2,
#   'people': 2,
#   '!': 2,
#   'soul': 2,
#   'other': 4,
#   'bunch': 1,
#   'options': 1,
#   'summer': 2,
#   'Margaret': 6,
#   'merlot': 3,
#   'richness': 1,
#   'maturity': 1,
#   'truffle': 1,
#   'grape': 4,
#   'being': 1,
#   "Nigel's": 1,
#   'roasted': 1,
#   'herb': 1,
#   'climatic': 1,
#   'intensity': 1,
#   'warm': 1,
#   'art': 4,
#   'Angel': 4,
#   'class': 1,
#   'minimal': 1,
#   'Barossa': 3,
#   'violet': 1,
#   'Caroline’s': 1,
#   'chinotto': 1,
#   'vibrant': 3,
#   'marmalade': 1,
#   'these': 7,
#   'framboise': 2,
#   'knowledge': 1,
#   'lavender': 1,
#   'each': 6,
#   'Obelisk': 2,
#   'champagne': 2,
#   'gentle': 1,
#   "Jen's": 2,
#   'spiciness': 1,
#   "Adam's": 3,
#   'loganberry': 1,
#   'brilliant': 1,
#   '$40': 1,
#   'Naked': 2,
#   'strawberries': 2,
#   'Angels': 18,
#   'reviews': 2,
#   'elderflower': 2,
#   'incredible': 3,
#   'Tamar': 2,
#   'reasonably': 2,
#   '$30': 2,
#   '3': 1,
#   'Viognier': 1,
#   'light': 2,
#   'mango': 1,
#   'you': 1,
#   "Luke's": 1,
#   'investment': 1,
#   'only': 1,
#   '40%': 1,
#   'Paul’s': 1,
#   'sunshine': 2,
#   'W': 2,
#   'fun': 2,
#   'Tempranillo': 1,
#   'backbreaking': 1,
#   'rare': 1,
#   'Margs’': 1,
#   'Perth': 2,
#   'chocolatey': 1,
#   'Ballandean': 1,
#   'Marsanne': 1,
#   'reds': 5,
#   'go-to': 1,
#   'sky-high': 1,
#   "Mike's": 1,
#   'jammy': 1,
#   'restraints': 1,
#   'Montvalley': 1,
#   'discretion': 3,
#   '.': 3,
#   'lower': 2,
#   'Geographe': 2,
#   'blueberries': 4,
#   'dishes': 1,
#   'bottles': 1,
#   'last': 1,
#   'using': 1,
#   'one': 1,
#   'small': 2,
#   'every': 3,
#   'why': 1,
#   'producing': 2,
#   'tingly': 2,
#   'Mt': 2,
#   'place': 1,
#   'blackberries': 1,
#   'an': 5,
#   'cheese': 1,
#   'war': 1,
#   'rabbit': 1,
#   "Heathcote's": 2,
#   'whole': 2,
#   'planting': 2,
#   '35%': 1,
#   'textual': 1,
#   'batch': 1,
#   'TLC': 1,
#   'any': 1,
#   'Angels!If': 1,
#   'top': 2,
#   'healthy': 2,
#   'passionate': 2,
#   'winemaker': 3,
#   'WA!Paul': 1,
#   'typical': 1,
#   'dust': 1,
#   'her': 2,
#   'free': 1,
#   'pressings': 1,
#   'pears': 1,
#   'creaminess': 2,
#   "John's": 1,
#   'sauvignon': 3,
#   'flavours:': 2,
#   'limey': 2,
#   'fragrant': 1,
#   'friendship': 2,
#   'fortified': 1,
#   'hazelnuts': 1,
#   'smiles': 2,
#   'centre': 1,
#   'Murrumbateman': 1,
#   'liberated': 1,
#   'crafting': 1,
#   'nibbles': 1,
#   'McLaren': 1,
#   'grenache': 1,
#   'farming': 1,
#   'vintage': 1,
#   'limes': 1,
#   'peninsular': 2,
#   'experimentation': 2,
#   "whites'": 1,
#   'Durif': 2,
#   'Feb': 1,
#   'March': 1,
#   'blackcurrants': 1,
#   'irresistible': 1,
#   'moreish': 1,
#   'delicious': 2,
#   'beauty': 1,
#   'crunchy': 2,
#   'rockmelon': 2,
#   'balanced': 1,
#   'southern': 3,
#   'trying': 1,
#   'skill': 1,
#   'food': 1,
#   "Brian's": 2,
#   'elsewhere': 1,
#   'Sangiovese': 1,
#   'creating': 2,
#   'strict': 1,
#   'ginger': 2,
#   'indulgence': 1,
#   "Rory's": 1,
#   'tobacco': 1,
#   'trivia': 1,
#   'many': 1,
#   'sage': 1,
#   "purity!Rod's": 1,
#   'competition': 1,
#   'buy-again': 1,
#   'Clare': 2,
#   'two': 3,
#   'experience': 2,
#   'lemongrass': 1,
#   'posh': 1,
#   'timeworn': 1,
#   'tongue': 1,
#   'Boorowa': 1,
#   '439m': 1,
#   'Errors': 1,
#   'Nero': 2,
#   'fruit-driven': 1,
#   "Andrew's": 1,
#   'hard': 1,
#   'nectarines': 1,
#   'tangerine': 1,
#   'personality': 1,
#   'NSW': 2,
#   'rosé': 1,
#   'Marlborough': 1,
#   'Langhorne': 1,
#   'growers': 1,
#   'easy': 1,
#   'gorgeous': 2,
#   'pride': 2,
#   'bitterness': 1,
#   'Lombardy': 1,
#   "Rob's": 1,
#   'Italy': 1,
#   'Hunter': 1,
#   'peppery': 1,
#   'liquid': 2,
#   'tomato': 1,
#   'cedar': 1,
#   'SSB': 1,
#   'Riverina': 1,
#   'fragrance': 1,
#   'just': 1,
#   'maintaining': 1,
#   'Brian': 1,
#   'several': 1,
#   'preparation': 1,
#   'Ben': 1,
#   "Thomas'": 1,
#   'days': 1,
#   'Chardy': 1,
#   'scrumptious': 1,
#   'gusto': 1,
#   "Liz's": 1,
#   'perfection': 1,
#   'attractive': 1,
#   'refreshing': 2,
#   'texture': 1,
#   'flourishing': 1,
#   'pleasure': 1,
#   'fans': 1,
#   'carefully': 1,
#   'beautiful': 1,
#   'mid': 1,
#   'various': 1,
#   '90%': 1},
#  'elegance': {'and': 7, 'of': 1, ',': 2, 'in': 1},
#  'and': {'finesse': 6,
#   'yeast': 1,
#   'then': 23,
#   'olive': 2,
#   ',': 8,
#   'the': 46,
#   'certainly': 2,
#   'melon': 12,
#   'toast': 2,
#   'roundness': 1,
#   'cinnamon': 3,
#   'sushi/sashimi': 1,
#   'poultry': 1,
#   'almond': 2,
#   'bright': 5,
#   'fennel': 2,
#   'clean': 4,
#   'scallops': 1,
#   'elegant': 12,
#   'blackcurrant': 8,
#   'smoky': 2,
#   'luscious': 4,
#   'red': 15,
#   'finishes': 8,
#   'complex': 17,
#   'coffee': 3,
#   'tobacco': 4,
#   'varied': 1,
#   'currant': 2,
#   'berry': 4,
#   'a': 160,
#   'subtle': 16,
#   'slippery': 2,
#   'chocolate': 10,
#   'spice': 46,
#   'hints': 17,
#   'well': 7,
#   'with': 8,
#   'lemon': 6,
#   'contains': 1,
#   'malt': 1,
#   'black': 14,
#   'blueberries': 3,
#   'anise': 3,
#   'decadence': 1,
#   'delicate': 10,
#   'rich': 6,
#   'hazelnut': 3,
#   'cassis-like': 1,
#   'mouth-filling': 1,
#   'excellent': 1,
#   'blackcurrent': 1,
#   'purple': 5,
#   'is': 18,
#   'asian': 2,
#   'violet': 5,
#   'tomato': 2,
#   'effortlessly': 2,
#   'balanced': 19,
#   'classical': 1,
#   'long': 10,
#   'grapefruit': 8,
#   'lengthy': 3,
#   'lime': 17,
#   'length': 14,
#   'cashew': 1,
#   'brûlée': 2,
#   'quince': 3,
#   'textures': 4,
#   'succulent': 3,
#   'overt': 2,
#   'balsamics': 1,
#   'liquorice': 2,
#   'mascarpone': 1,
#   'ground': 2,
#   'refined': 1,
#   'lively': 8,
#   'peach': 4,
#   'mineral': 2,
#   'crunchy': 5,
#   'flavours': 18,
#   'exotic/tropical': 1,
#   'lime-citrus': 1,
#   'pepper': 4,
#   'aromatic': 3,
#   'honeysuckle': 1,
#   'wet': 3,
#   'chardonnay': 2,
#   'finish': 2,
#   'loved': 3,
#   'lifted': 4,
#   'dark': 25,
#   'cardamom': 3,
#   'tannin': 6,
#   'good': 4,
#   'fragrant': 2,
#   'power': 5,
#   'Mediterranean': 2,
#   'Norfolk': 1,
#   'vanillin': 2,
#   'sweet': 6,
#   'spicy': 15,
#   'plum': 14,
#   'cedar': 3,
#   'bold': 2,
#   'will': 8,
#   'fruity': 8,
#   'roasted': 2,
#   'light': 8,
#   'generous': 7,
#   'orchard': 1,
#   'butterscotch': 2,
#   'tropical': 7,
#   'integrated': 1,
#   'creamy': 2,
#   'french': 7,
#   'pristine': 2,
#   'nectarine': 9,
#   'cherry': 13,
#   'spices': 8,
#   'textured': 5,
#   '8%': 1,
#   'shiraz': 8,
#   'bottling': 2,
#   'conservatism': 1,
#   'culture': 1,
#   'trellised': 1,
#   'gave': 2,
#   'fruit': 14,
#   'grew': 1,
#   'cool': 10,
#   'was': 3,
#   'herbs': 1,
#   'offers': 4,
#   'fine': 17,
#   'cut': 1,
#   'family': 1,
#   'white': 21,
#   'flint': 2,
#   'fresh': 27,
#   'shellfish': 1,
#   'mocha': 2,
#   'vibrant': 9,
#   'bay': 1,
#   'dark-berried': 1,
#   'fine-grained': 1,
#   'savoury': 13,
#   'mulberry': 1,
#   'pinot': 9,
#   'its': 7,
#   'reveals': 1,
#   'brioche': 2,
#   'pairs': 1,
#   'caramelised': 1,
#   'citrus': 25,
#   'coriander': 1,
#   'pleasant': 1,
#   'star': 2,
#   'vanilla': 7,
#   'plums': 4,
#   'milk': 1,
#   'pastas': 1,
#   'superbly': 1,
#   'stylish': 1,
#   'even': 8,
#   'youthful': 1,
#   'all-pervading': 1,
#   'awe-inspiring': 1,
#   'talc': 1,
#   'tense': 1,
#   'in': 8,
#   'most': 3,
#   'undoubted': 1,
#   'touch': 1,
#   'nuttiness': 1,
#   'powerful': 4,
#   'floral': 9,
#   'raspberry': 6,
#   'very': 3,
#   'through': 1,
#   'lychee': 4,
#   'rosewater': 1,
#   'sandalwood': 2,
#   'almost': 3,
#   'vegetarians': 2,
#   'winemaking': 1,
#   'aspirations': 1,
#   'Faye': 1,
#   'Mark': 1,
#   'canopy': 1,
#   'richness': 5,
#   'September': 1,
#   'healthy': 2,
#   'early': 3,
#   'April': 1,
#   'minerals': 1,
#   'kumquat': 1,
#   'bouncy': 1,
#   'pawpaw': 1,
#   'balance': 6,
#   'apple': 6,
#   'style': 6,
#   'carbon': 4,
#   'chlorine': 4,
#   'ripe': 11,
#   'pecan': 1,
#   'smells': 1,
#   'musky': 1,
#   'grape': 2,
#   'zesty': 6,
#   'layered': 2,
#   'slate': 2,
#   'mouth-watering': 4,
#   'great': 5,
#   'punchy': 2,
#   'gooseberry': 2,
#   'preserved': 1,
#   'firm': 3,
#   'skins': 2,
#   'pressed': 3,
#   'texture': 9,
#   'mint': 3,
#   'static': 1,
#   'American': 8,
#   'tannins': 3,
#   'how': 1,
#   'unoaked': 1,
#   'exceptionally': 1,
#   'ours': 1,
#   'vintage': 4,
#   'somewhat': 1,
#   'this': 9,
#   'wild': 5,
#   'like': 1,
#   'every': 3,
#   'beyond': 2,
#   'see…': 1,
#   'some': 1,
#   'crisper': 1,
#   'more': 7,
#   'prosciutto': 1,
#   'an': 3,
#   'pickled': 1,
#   'Indian': 1,
#   'nutmeal': 1,
#   'finely': 1,
#   'shape': 1,
#   'nervy': 1,
#   'restrained': 1,
#   'gris': 1,
#   'apples': 1,
#   'textural': 9,
#   'Herring': 1,
#   'classy': 1,
#   'coconut': 2,
#   'supple': 3,
#   'drive': 1,
#   'formic': 2,
#   'oak': 19,
#   'yet': 6,
#   'upbringing': 2,
#   'coat': 2,
#   'pressing': 2,
#   'create': 2,
#   'magenta': 1,
#   'herb': 2,
#   'finely-textured': 1,
#   'lingering': 7,
#   'refinement': 1,
#   'Prodigy': 1,
#   'extended': 1,
#   'finishing': 3,
#   'harvest': 1,
#   'flavour': 11,
#   'colour': 2,
#   '5%': 1,
#   'greens': 1,
#   'maturation': 4,
#   'weight': 4,
#   'flavoursome': 4,
#   'surprisingly': 1,
#   'bread': 2,
#   'butter': 2,
#   'native': 2,
#   'stone': 5,
#   'acidity': 6,
#   'earth': 2,
#   'garlic': 2,
#   'morello': 3,
#   'expressive': 3,
#   'poised': 1,
#   'varieties': 1,
#   'could': 1,
#   'sauvignon': 4,
#   'dry': 9,
#   'blueberry': 6,
#   'persistent': 6,
#   'nuances': 1,
#   'tempered': 1,
#   'unique': 2,
#   'detailed': 1,
#   'pot': 2,
#   'precisely': 1,
#   'captivating': 2,
#   'of': 1,
#   'oatmeal': 1,
#   'natural': 3,
#   'earthy': 6,
#   'delicacy': 1,
#   'October': 1,
#   'March': 2,
#   'overall': 1,
#   'marked': 2,
#   'seasoned': 3,
#   'licorice': 3,
#   'windy': 1,
#   'cassis': 2,
#   'undergrowth': 1,
#   'reach': 1,
#   'green': 10,
#   'cleansing': 1,
#   'replenished': 1,
#   'cabernet': 4,
#   'continued': 1,
#   'high': 1,
#   'conditions': 1,
#   '56': 1,
#   'delivered': 1,
#   'gently': 2,
#   'warmed': 1,
#   'aromatics': 1,
#   'one': 4,
#   'stainless': 1,
#   'to': 2,
#   'cold': 2,
#   'nettles': 1,
#   'Kate': 1,
#   'blackberry': 8,
#   'depth': 7,
#   'necessarily': 1,
#   'younger': 1,
#   'complexity': 17,
#   'minerality': 1,
#   'binding': 1,
#   'mild': 4,
#   'honeydew': 4,
#   'whack': 1,
#   'January': 1,
#   'spring': 4,
#   '40%': 1,
#   'foot': 1,
#   'fermentation': 1,
#   'filled': 1,
#   'lentils': 1,
#   'medium': 1,
#   'pasta': 1,
#   'seafood': 2,
#   'silky': 7,
#   'concentration': 2,
#   'dried': 7,
#   'sage': 1,
#   'wood': 1,
#   'structure': 3,
#   'adding': 1,
#   'mid-palate': 1,
#   'forest': 3,
#   'apricot': 3,
#   'ends': 1,
#   'smooth': 9,
#   'merlot': 1,
#   'redcurrant': 3,
#   'soft': 7,
#   'add': 1,
#   'blue': 4,
#   'strawberry': 5,
#   'velvety': 2,
#   'pink': 2,
#   'orange': 2,
#   'understated': 1,
#   'left': 4,
#   'leather': 2,
#   'musk': 3,
#   'persistence': 3,
#   'ancient': 1,
#   'confectionery': 1,
#   'full': 9,
#   'becomes': 1,
#   'unashamedly': 1,
#   'cream': 4,
#   'cola': 2,
#   'rhubarb': 2,
#   'quality': 6,
#   'crop': 2,
#   'Mourvèdre': 1,
#   'juniper': 1,
#   'rosemary': 1,
#   'strawberries': 3,
#   'pomegranate': 1,
#   'pear': 9,
#   'tartare': 2,
#   'while': 1,
#   'affordable': 1,
#   'hollandaise': 1,
#   'salty': 1,
#   'salad': 1,
#   'racy': 2,
#   'Thomas': 1,
#   'superb': 1,
#   'juicy': 12,
#   'tart': 1,
#   'radiant': 1,
#   'clearer': 1,
#   'capacity': 1,
#   'warming': 1,
#   'delicious': 5,
#   'fennel)': 1,
#   'vineyards': 1,
#   'his': 13,
#   'body': 2,
#   'intensity': 5,
#   'thin': 1,
#   'pineapple': 2,
#   'clove': 2,
#   'liqueur': 2,
#   'basil': 1,
#   'richly': 1,
#   'seductive': 2,
#   'shaved': 1,
#   'basting': 1,
#   'pine': 1,
#   'grated': 1,
#   'rose': 4,
#   'palate': 6,
#   'nature': 1,
#   'crab': 1,
#   'structured': 4,
#   'volume': 1,
#   'lemons': 1,
#   'nectarines': 2,
#   'nougat': 2,
#   'lightly': 1,
#   'maker': 1,
#   'uncompromising': 1,
#   'structural': 1,
#   'underwent': 1,
#   'prepared': 1,
#   'ensuring': 1,
#   'longevity': 1,
#   'stable': 1,
#   'lanolin': 1,
#   'litchi': 1,
#   'freshness': 2,
#   'Italy’s': 1,
#   'not': 5,
#   'un-stressed': 1,
#   'highly': 1,
#   'allimportant': 1,
#   'it': 3,
#   'musk-melons': 1,
#   'fresh-tasting': 1,
#   'invigorates': 1,
#   'excitement': 1,
#   'minds': 1,
#   'elegantly': 1,
#   'earthiness': 1,
#   'meatiness': 1,
#   'bottle': 1,
#   'shows': 1,
#   'geology': 1,
#   'sarsaparilla': 1,
#   'satisfying': 2,
#   'mataro': 2,
#   'grenache': 1,
#   'fruit-driven': 1,
#   'delayed': 1,
#   'attention': 2,
#   'pressure': 1,
#   'commencement': 1,
#   'saba': 1,
#   'glacé': 1,
#   'ageing': 1,
#   'saffron': 1,
#   'other': 2,
#   'touches': 1,
#   'confit': 1,
#   'bramble': 1,
#   'grilled': 2,
#   'enjoyable': 1,
#   'any': 3,
#   'tasty': 3,
#   "aroma's": 1,
#   'supported': 1,
#   'Ebenezer…all': 1,
#   'five': 1,
#   'people': 1,
#   'morels': 1,
#   'refreshing': 10,
#   'frangipani': 1,
#   'focus': 2,
#   'dense': 1,
#   'wait': 1,
#   'cedary': 1,
#   'has': 7,
#   'works': 1,
#   'fleshy': 1,
#   'mixed': 3,
#   'chunky': 1,
#   'develop': 1,
#   'tight': 1,
#   'stewed': 1,
#   'well-structured': 1,
#   'sea': 1,
#   'passionfruit': 5,
#   'nori': 1,
#   'crisp': 5,
#   'spicey': 1,
#   'raspberries': 3,
#   'nuts': 3,
#   'spiced': 2,
#   'plum-sauce': 1,
#   'clear': 1,
#   'peppery': 3,
#   'Tumbler': 1,
#   'Ironstone': 1,
#   'provide': 2,
#   'full-bodied': 4,
#   'cocoa': 1,
#   'persistant': 1,
#   'concentrated': 2,
#   'layers': 4,
#   'follows': 1,
#   'older': 2,
#   'produces': 1,
#   'flavoured': 1,
#   'gorgeous': 1,
#   'variety': 1,
#   'abundantly': 1,
#   'that': 1,
#   'hand': 2,
#   'picked': 2,
#   'careful': 1,
#   'he': 1,
#   'raisins': 1,
#   'plush': 2,
#   "stable'": 1,
#   'subsequent': 1,
#   'Margaret': 2,
#   'dimension': 1,
#   'introspective': 1,
#   'perfectly': 2,
#   'aromas': 2,
#   'disgorged': 2,
#   'fills': 2,
#   'always': 3,
#   'spread': 3,
#   'beautiful': 2,
#   'substantial': 1,
#   'leave': 3,
#   'just': 5,
#   'blustery': 1,
#   'risk': 2,
#   'Rebecca': 7,
#   'intense': 5,
#   'hand-picked': 1,
#   'co-fermented': 1,
#   'where': 1,
#   "Rebecca's": 2,
#   'well-balanced': 1,
#   'matured': 7,
#   'now': 3,
#   'producing': 2,
#   'hey': 2,
#   'love': 3,
#   'treated': 2,
#   'Cladia': 1,
#   'drinking': 1,
#   'cheers': 2,
#   'her': 2,
#   'enjoy': 8,
#   'ripen': 1,
#   'ripeness': 2,
#   'fermented': 5,
#   'time': 2,
#   'David': 4,
#   'cherries': 1,
#   'skill': 1,
#   'blackberries': 4,
#   'Vasse': 1,
#   'reducing': 1,
#   'snapping': 1,
#   'naturally': 1,
#   'aged': 1,
#   'bottled': 2,
#   'violets': 6,
#   'seriously': 1,
#   'toasty': 9,
#   'nutty': 3,
#   'homestyle': 4,
#   'classic': 1,
#   'nutrients': 1,
#   'used': 1,
#   'tank': 1,
#   'treat': 1,
#   'concrete': 1,
#   'dusty': 1,
#   'site': 1,
#   'right': 2,
#   'mysterious': 2,
#   'creative': 1,
#   'old': 4,
#   'organic': 1,
#   'sheep': 1,
#   'only': 5,
#   'rolls': 1,
#   'beautifully': 2,
#   'Naomi': 1,
#   'basket': 1,
#   'held': 1,
#   'it’s': 2,
#   'fig': 1,
#   'quinine': 1,
#   'kicking': 2,
#   'marzipan': 1,
#   'freshly': 1,
#   'sold': 2,
#   'stock': 3,
#   "Kevin's": 2,
#   'cigar': 2,
#   'experience': 1,
#   'provides': 1,
#   'delightful': 2,
#   'Viognier': 4,
#   'Derek': 8,
#   'strength': 1,
#   'fullness': 1,
#   'mouthfeel': 2,
#   'de-stemmed': 1,
#   'sweetness': 1,
#   'slightly': 3,
#   'care': 2,
#   'again': 3,
#   'inky': 1,
#   'blood': 1,
#   'plenty': 1,
#   'Leesignham': 1,
#   'fennel-seed': 1,
#   'lasts…': 1,
#   'Nigel': 1,
#   'toffee': 1,
#   'dive': 1,
#   'seems': 1,
#   'vineyard': 1,
#   'malbec': 2,
#   'make': 5,
#   'huge': 2,
#   'deliver': 2,
#   'pristinely': 2,
#   'Glen': 3,
#   'oh-so': 2,
#   'Clare': 2,
#   'reaching': 3,
#   'Jodie’s': 1,
#   'round': 2,
#   'smoked': 1,
#   "you'll": 5,
#   'stocks': 1,
#   'minerally': 1,
#   'perfecto': 1,
#   'asparagus': 1,
#   '60%': 1,
#   'intrigue': 1,
#   'notes': 1,
#   'riesling': 2,
#   'showcases': 1,
#   'world': 1,
#   'spiciness': 1,
#   'life': 3,
#   'lusciously': 3,
#   'ever': 3,
#   'moreish': 1,
#   'brighter': 1,
#   'drunk': 1,
#   "Andrew's": 1,
#   'perfume': 3,
#   'Marsanne': 1,
#   'have': 4,
#   'gamey': 1,
#   'Clarendon': 1,
#   'nutmeg': 2,
#   'out': 1,
#   'detail': 1,
#   'easy': 7,
#   'generosity': 1,
#   'Andrew': 1,
#   'hand-bottled': 1,
#   'revelling': 1,
#   'maybe': 1,
#   'without': 1,
#   'needs': 1,
#   'delivers': 1,
#   'fantastic': 1,
#   'collecting': 2,
#   'carefully': 2,
#   'Neil': 2,
#   'super': 1,
#   'sour': 2,
#   'get': 4,
#   'pay': 1,
#   'happy': 1,
#   'made': 2,
#   'greatest': 1,
#   'toasted': 1,
#   'buttery': 1,
#   'salted': 1,
#   'two': 1,
#   'tradition': 1,
#   'and': 3,
#   'maintain': 1,
#   'oh-so-subtle': 1,
#   'baked': 1,
#   'soul': 3,
#   'Dan': 2,
#   'truly': 2,
#   'almondy': 2,
#   'bask': 1,
#   'extremely': 2,
#   'partial': 1,
#   'Gewürztraminer': 1,
#   'harvested': 5,
#   'fro': 2,
#   'above': 2,
#   '30%': 1,
#   'Graciano': 1,
#   'approachable': 2,
#   'herbal': 1,
#   'puncheon': 1,
#   'years': 1,
#   'cacao': 3,
#   'surprise': 2,
#   'centre': 3,
#   'aniseed': 2,
#   'packed': 1,
#   'Hungarian': 1,
#   'charred': 2,
#   'nashi': 2,
#   'strictly': 2,
#   'pesticide-free': 2,
#   'manual': 2,
#   'refreshing…': 1,
#   'sure': 2,
#   'once': 1,
#   'rain': 1,
#   'singular': 1,
#   'we': 2,
#   'become': 1,
#   'surrounded': 1,
#   'smile-inducing': 1,
#   'can': 2,
#   'lightness': 2,
#   'scratching': 1,
#   'avocado': 2,
#   'produce': 1,
#   'so': 1,
#   'experimental': 1,
#   'southern': 1,
#   'zippy': 3,
#   'turquoise': 1,
#   'wanted': 2,
#   'captured': 2,
#   'feel': 1,
#   'looking': 3,
#   'precious': 1,
#   'indulgent': 1,
#   'keep': 2,
#   'breathed': 1,
#   'would': 1,
#   'packing': 1,
#   'vital': 1,
#   'Gus': 2,
#   'their': 3,
#   'leads': 2,
#   'tough': 1,
#   'maturing': 2,
#   'inviting': 1,
#   'bustle': 1,
#   'retain': 1,
#   'knowledge': 2,
#   'precision': 2,
#   'first': 1,
#   'did': 2,
#   'terrific': 1,
#   'yummy': 3,
#   "Paul's": 1,
#   'pale': 1,
#   'for': 1,
#   'eucalyptus': 1,
#   'let': 3,
#   'got': 1,
#   'display': 1,
#   'better': 1,
#   'King': 1,
#   'Arneis': 1,
#   'filtration': 1,
#   'you’ll': 1,
#   'continues': 3,
#   'Jodie': 2,
#   'outside': 1,
#   'lemongrass': 4,
#   'honey': 1,
#   'apply': 1,
#   'delight': 2,
#   'layer': 1,
#   'bring': 3,
#   'herbaceous': 1,
#   'tantalising': 1,
#   'makes': 1,
#   'Elgo': 1,
#   'limit': 1,
#   'sought': 1,
#   'price': 1,
#   'strong': 1,
#   'all': 1,
#   'new': 2,
#   'skin': 1,
#   'Awatere': 1,
#   'love!This': 1,
#   'at': 2,
#   'see': 2,
#   'independently': 1,
#   'less': 1,
#   'far': 1,
#   'capture': 1,
#   'hardiness': 1,
#   'smell': 1,
#   'gentle': 1,
#   'providing': 1,
#   'historically': 1,
#   'after': 1,
#   'fertile': 1,
#   'de-stemming': 1,
#   'ensure': 1,
#   'value': 2,
#   'interesting': 1,
#   'coming': 2,
#   'delay': 1,
#   'ensures': 1,
#   'asking': 1,
#   'low': 1,
#   'turkish': 1,
#   'pop': 1,
#   'fruits': 1,
#   'allowed': 1,
#   'core': 1,
#   'transformed': 1,
#   'limes': 1,
#   'vivacious': 1,
#   'totally': 1,
#   'mingle': 1,
#   'open': 1,
#   'enough': 2,
#   'delivering': 1,
#   'Frankland': 1,
#   'summer': 3,
#   'daring': 2,
#   'thanks': 2,
#   'sweeter': 1,
#   'biodynamic': 1,
#   'grassy': 3,
#   'backed': 1,
#   'Gewurztraminer': 1,
#   'extraordinary': 1,
#   'weighty': 1,
#   'your': 3,
#   'elderflower': 1,
#   'vibrantly': 1,
#   'food': 1,
#   'versatility': 1,
#   'vibrancy': 1,
#   'crafted': 2,
#   'completely': 1,
#   'includes': 1,
#   'young': 1,
#   'lipsmackingly': 1,
#   'tartness': 1,
#   'packham': 1,
#   'allowing': 1,
#   'protected': 1,
#   'lasting': 2,
#   'perfect': 3,
#   'pickles': 1,
#   'appreciate': 1,
#   'harmony': 1,
#   'raised': 1,
#   'Wairau': 1,
#   'lap': 1,
#   'McLaren': 1,
#   'sheer': 1,
#   'mash': 1,
#   'exotic': 2,
#   'boom': 1,
#   'undertones': 1,
#   'championing': 1,
#   'why': 2,
#   'knows': 2,
#   'inspiration': 2,
#   'try': 2,
#   'exclusive': 1,
#   'scoring': 1,
#   'quaffable': 1,
#   'rise': 1,
#   'smoothly': 1,
#   'experiencing': 1,
#   'you’d': 1,
#   'liven': 1,
#   'iconic': 1,
#   'uncomplicated': 1,
#   'share': 1,
#   'enhance': 1,
#   'press': 1,
#   'zingy': 1,
#   'leaves': 1,
#   'delicately': 1,
#   'glasses': 1,
#   'still': 1,
#   'based': 1,
#   'grower': 1,
#   'craft': 1,
#   'pocket-friendly': 1,
#   'does': 1,
#   'pumped': 1,
#   'combining': 1,
#   "don't": 1,
#   'Brad': 1,
#   'honeycombe': 1,
#   'especially': 1,
#   'softer': 1,
#   'guava': 1,
#   'slender': 1,
#   'ready': 1,
#   'lighter': 1,
#   'ability': 1,
#   'everything': 1,
#   'fun': 1,
#   'drinkers': 1,
#   'barbequed': 2,
#   'plump': 1,
#   'tested': 1,
#   'revel': 1,
#   'thick': 1,
#   'when': 1,
#   'lifts': 1,
#   "it's": 2,
#   'kick': 2,
#   'modern': 1,
#   'stonefruit': 1,
#   'passion': 1,
#   'morter': 1},
#  'finesse': {',': 5,
#   '.': 1,
#   'typical': 1,
#   'and': 1,
#   'of': 1,
#   'mean': 1,
#   'you': 1},
#  ',': {'displaying': 3,
#   'green': 10,
#   'amidst': 1,
#   'finely': 1,
#   'cranberry': 2,
#   'Christmas': 2,
#   'and': 142,
#   'fennel': 4,
#   'not': 14,
#   'nutmeg)': 2,
#   'something': 3,
#   'custard': 2,
#   'raw': 2,
#   'star': 2,
#   'nectarine': 4,
#   'followed': 36,
#   'almonds': 1,
#   'butterscotch': 2,
#   'brioche': 2,
#   'finessed': 1,
#   'fois': 1,
#   'natural': 1,
#   'straw': 1,
#   'a': 48,
#   'focused': 2,
#   'with': 116,
#   "it's": 21,
#   'fresh': 22,
#   'complex': 8,
#   'dried': 10,
#   'tomato': 4,
#   'cedar': 5,
#   'yet': 23,
#   'but': 37,
#   'fine': 5,
#   'bold': 5,
#   'elegant': 8,
#   'tropical': 5,
#   'á': 2,
#   'Worcestershire': 2,
#   'steel-cut': 2,
#   'definitely': 3,
#   'clay-like': 2,
#   'grainy': 3,
#   'plum': 15,
#   'vanilla': 5,
#   'lemon': 16,
#   'the': 95,
#   'olives': 2,
#   'white': 16,
#   'cumquat': 1,
#   'grandeur': 1,
#   'extravagantly': 1,
#   'there': 18,
#   'almost': 3,
#   'chocolate': 10,
#   'mint': 4,
#   'mushroom': 1,
#   'spicy': 7,
#   'persistent': 3,
#   'dark': 23,
#   'complexed': 2,
#   'spice': 15,
#   'soft': 5,
#   'to': 5,
#   'betel-leaf': 2,
#   'lime': 5,
#   'grapefruit': 6,
#   'nuttiness': 2,
#   'consistent': 2,
#   'cola': 2,
#   'graphite/ironstone?': 1,
#   'elongated': 2,
#   'chinotto': 1,
#   'mocha': 4,
#   'sweet': 6,
#   'lovely': 1,
#   'Andrew': 4,
#   'pineapple': 2,
#   'cashew': 4,
#   'drive': 1,
#   'are': 2,
#   'held': 1,
#   'V': 4,
#   'regressive': 2,
#   'courting': 2,
#   'sweetbread': 2,
#   'asphalt': 2,
#   'fig': 6,
#   'inviting': 1,
#   'heightened': 2,
#   'imposing': 1,
#   'enticing': 1,
#   'spliced': 1,
#   'black': 25,
#   'replete': 1,
#   'gravy': 1,
#   'citrus': 19,
#   'combining': 3,
#   'caramelized': 1,
#   'crispy': 1,
#   'salt': 2,
#   'or': 8,
#   'rich': 9,
#   'including': 11,
#   'light': 3,
#   'dry': 16,
#   'this': 105,
#   'passionfruit': 3,
#   'blackcurrant': 6,
#   'honeysuckle': 2,
#   'balance': 4,
#   'layers': 2,
#   'nutmeg': 2,
#   'cinnamon': 6,
#   'raspberries': 4,
#   'eg': 2,
#   'rack': 2,
#   'spatchcock': 1,
#   'pan': 2,
#   'grilled': 5,
#   'barbecued': 1,
#   'game': 2,
#   'rabbit': 1,
#   'most': 2,
#   'using': 1,
#   'pale': 2,
#   'sensual': 1,
#   'plums': 7,
#   'supple': 6,
#   'toasty': 4,
#   'cassis': 2,
#   'honey': 4,
#   'notes': 2,
#   'ripe': 14,
#   'peach': 5,
#   'crisp': 6,
#   'meringue': 1,
#   'Huon': 6,
#   'Tyson': 5,
#   'raspberry': 8,
#   'anise': 1,
#   'savoury': 9,
#   '26%': 1,
#   'mataro': 1,
#   'many': 1,
#   'perseverance': 1,
#   'from': 7,
#   'old': 3,
#   'gnarled': 1,
#   'dry-grown': 2,
#   'making': 12,
#   'developing': 1,
#   'while': 12,
#   'well-balanced': 2,
#   '15+': 1,
#   'ready': 2,
#   'nettles': 1,
#   'poultry': 1,
#   'licorice': 6,
#   'it': 33,
#   'allowing': 6,
#   'mature': 1,
#   'purple': 1,
#   'carpaccio': 1,
#   'blueberry': 6,
#   'praline': 1,
#   'roasted': 3,
#   'delicate': 2,
#   'apricot': 3,
#   'completed': 1,
#   'Victoria': 3,
#   'pear': 7,
#   'complete': 1,
#   'which': 18,
#   'chardonnay': 4,
#   'its': 5,
#   'scallops': 1,
#   'oysters': 1,
#   'yellow': 2,
#   'roast': 2,
#   'veal': 2,
#   'lamb': 1,
#   'juicy': 7,
#   'polished': 1,
#   'especially': 16,
#   'wild': 5,
#   'clove': 2,
#   'these': 9,
#   'toffee': 1,
#   'bursting': 1,
#   'strawberries': 1,
#   'seeming': 1,
#   'lemony': 1,
#   'refined': 3,
#   'full': 12,
#   'powerful': 4,
#   'considering': 1,
#   'bar': 1,
#   'skipped': 1,
#   'does': 1,
#   '2004': 1,
#   'uniting': 1,
#   'orchard': 1,
#   'blossom': 1,
#   'chalk': 3,
#   'structured': 3,
#   'still': 1,
#   'finishes': 1,
#   'so': 58,
#   'spectacularly': 1,
#   'widow': 1,
#   'Madame': 1,
#   'bright': 8,
#   'in': 4,
#   'nashi': 3,
#   'oaky': 2,
#   'musk': 4,
#   'complemented': 1,
#   'inventive': 1,
#   'both': 4,
#   'bees': 1,
#   'de-stemmed': 1,
#   'leading': 13,
#   'coconut': 1,
#   'guava': 2,
#   'blueberries': 3,
#   'following': 2,
#   'achieving': 2,
#   'meaty': 1,
#   'smooth': 5,
#   'Fillet': 1,
#   'it’s': 4,
#   'then': 10,
#   'nor': 1,
#   'light-bodied': 1,
#   'we': 6,
#   'we’ve': 1,
#   'aromatic': 3,
#   'Mother': 3,
#   'fleshy': 2,
#   'medium-bodied': 2,
#   'even': 5,
#   'cloudy': 2,
#   'we’re': 1,
#   'may': 1,
#   'onion': 3,
#   'figs': 1,
#   'marzipan': 1,
#   'firmer': 1,
#   'anchovy': 1,
#   'pea': 1,
#   'hotter': 1,
#   'I’d': 1,
#   'Indian': 1,
#   'that': 5,
#   'curried': 1,
#   'crystal-clear': 1,
#   'crunchy': 4,
#   'approachable': 2,
#   'forest': 2,
#   'choc': 1,
#   'volume': 1,
#   'melted': 1,
#   'nutty': 2,
#   'chalky': 4,
#   'hoisin': 2,
#   'balsamic': 2,
#   'all': 13,
#   'muscular': 2,
#   'feisty': 2,
#   'submerged': 2,
#   'vibrant': 7,
#   'crimson': 1,
#   'Langhorne': 1,
#   'SAVariety:': 1,
#   '8': 1,
#   'framed': 1,
#   'dynamic': 1,
#   'Odyssey': 1,
#   'Classification': 1,
#   'excellent': 3,
#   '10-20': 1,
#   '40%': 2,
#   'paté': 1,
#   'oak': 5,
#   'winemaker': 1,
#   'powdery': 3,
#   'firm': 5,
#   'lily': 2,
#   'pomelo': 2,
#   'showing': 10,
#   'highlighted': 1,
#   'menthol': 1,
#   'florals': 1,
#   'one': 5,
#   'vanillin': 1,
#   'hints': 4,
#   'clean': 5,
#   'ginger': 2,
#   'long': 4,
#   'Magill': 2,
#   'medium-weight': 2,
#   'matured': 2,
#   'contemporary': 1,
#   'vinified': 1,
#   'dates': 2,
#   'propelled': 2,
#   'Lisa': 1,
#   'deeply': 1,
#   'pears': 1,
#   'char-grilled': 1,
#   'chewy': 2,
#   'winter': 1,
#   'wet': 1,
#   'flint': 1,
#   'creamy': 1,
#   'underlying': 1,
#   'striking': 1,
#   'contributing': 2,
#   'heavy': 1,
#   'deep': 2,
#   'good': 3,
#   'dutch': 1,
#   'Martell': 1,
#   'beautiful': 1,
#   'keenly': 1,
#   'however': 1,
#   'crushed': 3,
#   'structure': 3,
#   'cross': 1,
#   'lychees': 1,
#   'sauvignon': 3,
#   'pepper': 8,
#   'freshly': 4,
#   'tinned': 1,
#   'biscuit': 1,
#   'lightly': 1,
#   'fish': 1,
#   'offering': 3,
#   'detailed': 1,
#   'perfumed': 2,
#   'graphite': 1,
#   'mineral': 5,
#   'very': 1,
#   'plump': 1,
#   'smokey': 2,
#   'unique': 5,
#   'perhaps': 1,
#   'cool': 3,
#   'settled': 1,
#   'offers': 1,
#   'lingering': 3,
#   'loaded': 1,
#   'blackberry': 6,
#   'nuances': 1,
#   'youthful': 1,
#   'creaminess': 1,
#   'whole': 2,
#   'hand-made': 1,
#   'warm': 1,
#   'freshness': 1,
#   'balanced': 11,
#   'texture': 2,
#   'cherry': 7,
#   'wrapped': 2,
#   'really': 1,
#   'some': 5,
#   'red': 12,
#   'lithe': 1,
#   'minerals': 2,
#   'winding': 1,
#   'concentrated': 2,
#   'great': 3,
#   'french': 1,
#   'five': 1,
#   'cherries': 8,
#   'lip': 1,
#   'complexity': 1,
#   'high': 3,
#   'bay': 2,
#   'lanolin': 1,
#   'sea': 3,
#   'oyster': 1,
#   'truffle': 2,
#   '2005': 1,
#   '2006': 1,
#   '2008': 1,
#   'Coal': 1,
#   'Tamar': 1,
#   'Derwent': 1,
#   'pinot': 7,
#   'rhubarb': 2,
#   'create': 1,
#   'dense': 2,
#   'resulting': 1,
#   'delivering': 6,
#   'generous': 4,
#   'quince': 2,
#   'mid-red': 1,
#   'spices': 3,
#   'tangy': 1,
#   'etc': 1,
#   'cellar': 1,
#   'liquorice': 7,
#   'pure': 1,
#   'shiraz': 3,
#   'inky': 1,
#   'lychee': 1,
#   'intense': 2,
#   'oak-tinged': 1,
#   'refreshing': 5,
#   'shellfish': 3,
#   'adding': 2,
#   'needs': 1,
#   'drink': 1,
#   '$22': 1,
#   '11': 1,
#   'screwcap': 1,
#   'cleansing': 1,
#   'low': 1,
#   'Dr': 1,
#   'slate-soil': 1,
#   'fruit-driven': 3,
#   'mango': 3,
#   'large-production': 1,
#   '2007': 2,
#   'wine': 4,
#   'Decanter': 1,
#   'Gault': 1,
#   'fruits': 1,
#   'iodine': 1,
#   'biting': 1,
#   'finesse': 1,
#   'violets': 3,
#   'earthy': 2,
#   'quite': 1,
#   'Penfolds': 2,
#   'max': 1,
#   'Peter': 1,
#   'across': 1,
#   'Bin': 1,
#   'colour': 1,
#   'basil': 1,
#   'pomegranate': 4,
#   'dusty': 1,
#   'sour': 2,
#   'no': 1,
#   'focussed': 1,
#   'nevertheless': 1,
#   'transparency': 1,
#   'paw': 1,
#   'banana': 2,
#   'chicken': 3,
#   'fried': 1,
#   'Mexican': 1,
#   'spring': 1,
#   'pasta’s': 1,
#   'curries': 1,
#   'salsas': 1,
#   'risotto': 1,
#   'asparagus': 1,
#   'sesame': 1,
#   'eggplant': 1,
#   'everything': 1,
#   'thick': 1,
#   'apricots': 1,
#   'honeydew': 1,
#   'melon': 5,
#   'apple': 10,
#   'violet': 1,
#   'silky': 4,
#   'floral': 3,
#   'although': 1,
#   'is': 4,
#   'early': 1,
#   'turkish': 2,
#   'flavour': 7,
#   'perfect': 6,
#   'such': 1,
#   'clams': 1,
#   'pan-fried': 1,
#   'Sashimi/sushi': 1,
#   'cream-sauce': 1,
#   'if': 2,
#   'asian': 1,
#   'seafood': 1,
#   'impeccably': 1,
#   'on': 1,
#   'between': 1,
#   'avocado/surimi': 1,
#   'vegetable': 1,
#   'salmon': 2,
#   'Mediterranean': 1,
#   'Priorat': 1,
#   'without': 4,
#   'rustic': 1,
#   'highly': 1,
#   'medium-body': 1,
#   'proud': 1,
#   'full-bodied': 1,
#   'Coonawarra': 1,
#   'mulberry': 4,
#   'mulberries': 1,
#   'fruitcake': 1,
#   'blood': 2,
#   'grenache': 1,
#   'Mourvèdre': 1,
#   'low-yielding': 1,
#   'finishing': 1,
#   'south': 3,
#   'Barossa': 3,
#   'soil': 1,
#   'often': 1,
#   'meant': 1,
#   '20%': 2,
#   '15%': 1,
#   'acidity:': 1,
#   'pH:': 1,
#   'Executive': 1,
#   'candied': 3,
#   'apples': 1,
#   'seamless': 2,
#   'tobacco': 5,
#   'blackberried': 1,
#   'bourbon-like': 1,
#   'fragrant': 1,
#   'minerality': 1,
#   'bittersweet': 1,
#   'powder': 1,
#   'located': 1,
#   'lemon/lime': 1,
#   'pork': 1,
#   'trout': 1,
#   'blue': 2,
#   'AOC': 1,
#   'pulpy': 1,
#   'mellow': 1,
#   'Fox': 1,
#   'sage': 1,
#   'select': 1,
#   'Greenock': 1,
#   'Moppa': 1,
#   'seductive': 1,
#   'gamey': 1,
#   'slightly': 1,
#   'driven': 1,
#   'strawberry': 3,
#   'coupled': 1,
#   'ruby': 1,
#   'boysenberry': 1,
#   'palate': 1,
#   'textural': 3,
#   'plus': 3,
#   'delivered': 4,
#   'poise': 2,
#   'lifted': 5,
#   'salads': 1,
#   'straight': 1,
#   'hazelnut': 1,
#   'delicious': 3,
#   'racy': 2,
#   'propels': 1,
#   'scorched': 2,
#   'leather': 1,
#   'older': 1,
#   'integrated': 1,
#   'alpie': 1,
#   'jarrah': 1,
#   'entwined': 1,
#   'well': 3,
#   'glazed': 1,
#   'whilst': 1,
#   'along': 7,
#   'Tempranillo': 1,
#   'Greenstone': 1,
#   'earth': 1,
#   'satuma': 1,
#   'loganberry': 1,
#   'underscored': 1,
#   'W': 3,
#   'France': 4,
#   'partial': 1,
#   'pressed': 2,
#   'succulent': 1,
#   'he': 5,
#   'giving': 3,
#   'poised': 1,
#   'pink': 1,
#   'as': 10,
#   'at': 3,
#   'was': 1,
#   'basket': 2,
#   'aged': 1,
#   'only': 14,
#   'hand': 5,
#   'anytime!With': 1,
#   'brooding': 1,
#   'ensuring': 3,
#   'blackberries': 3,
#   'peppery': 1,
#   'lending': 1,
#   'treat': 2,
#   "Stuart's": 3,
#   'blackcurrants': 1,
#   'back': 1,
#   "Brian's": 2,
#   'you': 15,
#   'lush': 2,
#   'rather': 4,
#   'dinner': 1,
#   'riddled': 2,
#   "you've": 4,
#   'perched': 1,
#   "don't": 6,
#   'lasting': 1,
#   'made': 5,
#   'leaving': 4,
#   'producing': 2,
#   'hazelnuts': 1,
#   'naturally': 1,
#   'yearned': 2,
#   'heralding': 2,
#   'single': 10,
#   'certified': 2,
#   'Nicky': 2,
#   'tannin': 4,
#   'Cynthea': 1,
#   'Stuart': 1,
#   'intermingled': 1,
#   'when': 1,
#   'returning': 1,
#   'stone': 2,
#   'bolstered': 1,
#   'more': 2,
#   'simply': 2,
#   'of': 1,
#   'unfined': 1,
#   'unfiltered': 1,
#   'attractive': 1,
#   "you'll": 20,
#   'Rob': 5,
#   "he's": 2,
#   'mandarin': 2,
#   'Brazil': 1,
#   'crafted': 1,
#   'Naomi': 1,
#   'stainless': 1,
#   'for': 5,
#   '2016': 1,
#   'power': 1,
#   'elegance': 1,
#   'right': 1,
#   'Angels': 5,
#   'fantastic': 1,
#   'given': 1,
#   'composting': 1,
#   'mulching': 1,
#   'unearthing': 1,
#   'who': 2,
#   'keep': 1,
#   'subtle': 2,
#   'searing': 1,
#   'foot-crushed': 1,
#   'hand-plunged': 1,
#   'her': 2,
#   'small': 6,
#   'graceful': 1,
#   'exotic': 2,
#   'modern': 3,
#   'you’ll': 1,
#   'top': 1,
#   'serious': 1,
#   'juniper': 1,
#   'capocollo': 1,
#   'over': 1,
#   'creating': 3,
#   'hands': 2,
#   'focusing': 2,
#   'preceded': 2,
#   'brand': 1,
#   'single-vineyard': 2,
#   'two': 1,
#   'NSW': 1,
#   'intensity': 1,
#   'extending': 1,
#   'plush': 1,
#   'yummm!Ash': 1,
#   '20': 1,
#   'cold': 1,
#   'Ash': 3,
#   'seriously': 1,
#   'sadly': 1,
#   'just': 4,
#   'make': 1,
#   'within': 1,
#   'supported': 1,
#   'pop': 1,
#   'Dolan': 1,
#   'robust': 2,
#   'luscious': 3,
#   'extraordinarily': 1,
#   'had': 1,
#   'warming': 3,
#   'malt': 1,
#   'treacle': 1,
#   'usually': 1,
#   'drawing': 3,
#   'scoring': 3,
#   'each': 6,
#   'blends': 1,
#   'Paul': 3,
#   'once': 1,
#   'save': 1,
#   'why': 7,
#   'thousands': 1,
#   'get': 8,
#   'an': 3,
#   'Gewurztraminer': 3,
#   'SA': 1,
#   'where': 4,
#   'expressing': 1,
#   'part': 1,
#   'letting': 3,
#   'they': 6,
#   'velvety': 4,
#   'Viognier': 2,
#   'barrel': 1,
#   'Rousanne': 1,
#   'sophisticated': 1,
#   'cabernet': 1,
#   'sexy': 1,
#   'do': 1,
#   'enough': 1,
#   'intrinsic': 1,
#   'hand-crafted': 1,
#   'flavour-packed': 1,
#   "you're": 5,
#   'doing': 1,
#   'complimenting': 1,
#   'riesling': 2,
#   'what-nature-gives-is-what-you-get': 2,
#   'their': 2,
#   'full-flavoured': 2,
#   'alluring': 2,
#   'extremely': 2,
#   'basket-pressed': 2,
#   'Damson': 1,
#   'hand-pruned': 1,
#   'bringing': 2,
#   'peaches': 5,
#   'enjoy': 1,
#   'comprised': 1,
#   'prior': 3,
#   'round': 2,
#   'John': 2,
#   'riper': 2,
#   'Randal': 1,
#   'grown': 1,
#   'incomparable': 1,
#   'Nero': 2,
#   '35%': 1,
#   'received': 1,
#   "Paul's": 1,
#   'stepping': 1,
#   'overpowering': 1,
#   'fruity': 4,
#   'super': 1,
#   'Steve': 1,
#   'bramble': 2,
#   'closing': 2,
#   'stories': 2,
#   'balancing': 2,
#   'continuously': 2,
#   'therefore': 2,
#   'late': 1,
#   'Mike': 1,
#   'concentration': 1,
#   'granny': 2,
#   'your': 3,
#   'kick': 1,
#   'butter': 2,
#   'grassy': 2,
#   'gooseberry': 3,
#   'richness': 2,
#   'length': 2,
#   'will': 2,
#   'merlot': 1,
#   'easy': 4,
#   'festive': 1,
#   '500': 1,
#   'smoky': 1,
#   'pulling': 1,
#   'due': 1,
#   'yum!Leighton': 1,
#   'pushing': 1,
#   'coating': 1,
#   'keeping': 1,
#   'Gus': 1,
#   'lunching': 1,
#   'fermenting': 1,
#   'enormously': 1,
#   'paying': 1,
#   'artisanal': 1,
#   'lovingly': 2,
#   'generation': 1,
#   'find': 1,
#   'he’s': 1,
#   'mouth-watering': 1,
#   'yummm': 1,
#   'richa': 1,
#   'development': 2,
#   'punchy': 2,
#   'turning': 2,
#   'used': 1,
#   "that's": 1,
#   'orange': 1,
#   'mouth': 1,
#   'rounded': 1,
#   'mild': 2,
#   'ripening': 2,
#   'big': 1,
#   'thanks': 1,
#   'drier': 1,
#   'flavoursome': 1,
#   'before': 3,
#   'Rory': 1,
#   'direction': 1,
#   "Jen's": 1,
#   'my': 1,
#   "isn't": 1,
#   'Rutherglen': 1,
#   'aromas': 1,
#   'rated': 1,
#   'purposefully': 2,
#   'locking': 2,
#   'capturing': 1,
#   'stocks': 1,
#   "Ash's": 1,
#   'Adam': 2,
#   'Fiano': 1,
#   'finding': 1,
#   'moreish': 2,
#   'cocoa': 2,
#   'Sam': 3,
#   'Bald': 1,
#   'fancy': 1,
#   'into': 1,
#   'mixing': 1,
#   'dive': 2,
#   'prepare': 1,
#   'famous': 1,
#   'smart': 1,
#   "Luke's": 1,
#   'nipping': 1,
#   'complimented': 2,
#   'because': 2,
#   'look': 2,
#   'Petit': 1,
#   'capsicum': 1,
#   'Cab': 1,
#   'Pemberton': 1,
#   'like': 2,
#   "you'd": 3,
#   'start': 1,
#   'Gary': 2,
#   'yumo!Every': 1,
#   'medium': 1,
#   'alongside': 1,
#   'nutrient': 1,
#   'proving': 1,
#   'silvery': 1,
#   'light-medium': 2,
#   'Plantagenet': 1,
#   'Alkoomi': 1,
#   'hard': 2,
#   'Ben': 1,
#   'jasmine': 1,
#   'yummm!With': 1,
#   'blend': 1,
#   'Harden': 1,
#   'yummm!Looking': 1,
#   'Jazz': 1,
#   'providing': 1,
#   'Semillon': 2,
#   'poached': 2,
#   'give': 1,
#   'let': 1,
#   'resulted': 1,
#   'rockmelon': 1,
#   'year': 1,
#   'by': 1,
#   'marmalade': 1,
#   'go': 1,
#   'Clare': 1,
#   'spaghetti': 1,
#   'bangers': 1,
#   'growing': 1,
#   'allows': 1,
#   'throw': 1,
#   'has': 1,
#   'established': 2,
#   'combined': 2,
#   'opening': 1,
#   'elegantly': 1,
#   "Geoff's": 1,
#   'textured': 3,
#   'aiming': 1,
#   'Alto': 1,
#   'Friuli-Venezia': 1,
#   "Rory's": 1,
#   'Thomas': 1,
#   'interlaced': 1,
#   'passionate': 1,
#   'blending': 1,
#   'NZ': 1,
#   "Rob's": 1,
#   'exhibiting': 1,
#   'consistently': 1,
#   'zippy': 1,
#   'racing': 1,
#   'fermented': 1,
#   'three': 1,
#   'pilsner-style': 1,
#   'sweetness': 1,
#   'fitting': 1,
#   'fruit': 1,
#   'Durif': 1,
#   'teamed': 1,
#   'Italy': 1,
#   'ridged': 1,
#   'understated': 1,
#   'always': 1,
#   'uncomplicated': 1,
#   'Sangiovese': 1,
#   'injecting': 1,
#   'backed': 1,
#   'any': 1,
#   "they've": 1,
#   'sky-high': 1,
#   'golden': 1,
#   'voluptuous': 2,
#   'herbs': 2,
#   'lively': 1,
#   'fined': 1},
#  'displaying': {'notations': 1,
#   'an': 1,
#   'a': 1,
#   'characters': 1,
#   'notes': 1,
#   'flavours': 1,
#   'white': 1,
#   'black': 1},
#  'notations': {'of': 1},
#  'citrus': {'sorbet': 1,
#   'lime': 4,
#   ',': 15,
#   'blossom': 6,
#   'and': 27,
#   'fruit': 7,
#   'notes': 4,
#   'flavour': 3,
#   'florals': 1,
#   'characters': 2,
#   'pith': 1,
#   'flavours': 10,
#   '.': 4,
#   'on': 1,
#   'core': 1,
#   'with': 1,
#   'finish': 6,
#   'aromatics': 1,
#   'rind': 1,
#   'aromas': 2,
#   'oils': 1,
#   'layers': 4,
#   'fruits': 2,
#   'flowers': 1,
#   'acidity': 1,
#   'pop': 1,
#   'apple': 1,
#   'freshness': 1,
#   'based': 1,
#   'from': 1,
#   'will': 1,
#   'hops': 1,
#   'drive': 1},
#  'sorbet': {',': 1, 'and': 1},
#  'green': {'apple': 18,
#   'hues': 3,
#   'in': 3,
#   'salad': 1,
#   'tea': 2,
#   'with': 1,
#   'tinge': 1,
#   'edges': 2,
#   'pea': 1,
#   'chilli': 1,
#   'reflections': 1,
#   'straw': 1,
#   '.': 1,
#   'bottles': 4,
#   'highlights': 1,
#   'edge': 2,
#   'hue': 2,
#   'tints': 2,
#   'label': 1,
#   'apples': 9,
#   'tinges': 2,
#   'melon': 2,
#   'pear': 1,
#   'rockmelon': 2,
#   'lemons': 1},
#  'apple': {'and': 21,
#   ',': 12,
#   'tart': 1,
#   'skins': 1,
#   'notes': 1,
#   'flavours': 1,
#   'blossom': 7,
#   'crisp': 1,
#   'aromas': 4,
#   '.': 1,
#   'grab': 1,
#   'supported': 1,
#   'with': 1,
#   'like': 2},
#  'yeast': {',': 3,
#   '.': 3,
#   'added': 1,
#   'lees': 5,
#   'as': 1,
#   'fermentation': 1,
#   'fermented': 2},
#  'amidst': {'a': 1},
#  'a': {'creamy': 15,
#   'most': 2,
#   'pale': 7,
#   'wonderful': 10,
#   'cut': 2,
#   'hint': 49,
#   'red': 7,
#   'tightly': 1,
#   'chocolate': 1,
#   'soft': 16,
#   'whiskey': 1,
#   'crimson': 1,
#   'fine': 14,
#   'brightness': 5,
#   'lick': 1,
#   'nicely': 1,
#   'tannin': 1,
#   'long': 47,
#   'very': 15,
#   'south': 1,
#   'powdery': 2,
#   'pan-jus': 1,
#   'vinous': 1,
#   'formic': 2,
#   '.': 12,
#   'darker': 2,
#   'taste': 1,
#   'spoil': 2,
#   'grain-like': 2,
#   'mouth-watering': 5,
#   'balanced': 8,
#   'dense': 4,
#   'compelling': 1,
#   'green': 3,
#   'slight': 8,
#   'fresh': 8,
#   'range': 7,
#   'simple': 1,
#   'firm': 2,
#   'clean': 6,
#   'real': 2,
#   'delicious': 13,
#   'small': 8,
#   'distinct': 2,
#   'perfect': 14,
#   'vibrant': 10,
#   'faint': 1,
#   'versatile': 3,
#   'luminous': 3,
#   'touch': 33,
#   'beautiful': 10,
#   'festive': 1,
#   'delightful': 3,
#   'light': 8,
#   'treat': 4,
#   'great': 23,
#   'nutty': 2,
#   'terrific': 1,
#   'tribute': 1,
#   'two-week': 1,
#   'result': 2,
#   'roller-coaster': 1,
#   'warm': 5,
#   'week': 3,
#   'month': 1,
#   'complex': 16,
#   'silver': 1,
#   'finely': 2,
#   'powerful': 6,
#   'reflection': 1,
#   'fine-grained': 1,
#   'decade': 3,
#   'pure': 2,
#   'carnivoric': 1,
#   'well': 2,
#   'stream': 1,
#   'full-bodied': 1,
#   'medium': 12,
#   'zesty': 6,
#   'golden': 2,
#   'reserved': 1,
#   'crisp': 16,
#   'deep': 9,
#   'cellaring': 1,
#   'dark': 4,
#   'buffet': 1,
#   'magical': 2,
#   'mind-boggling': 1,
#   'flicker': 1,
#   'hand': 3,
#   'wine': 50,
#   'majority': 1,
#   'true': 13,
#   'fantastic': 1,
#   'subtle': 16,
# ...
#   'new': 1,
#   'fruit': 1,
#   'organic': 2,
#   'vines': 1,
#   'all': 1},
#  'highest': {'quality': 2},
#  'quality': {'English': 1,
#   'wines': 2,
#   'of': 8,
#   'and': 10,
#   'fruit': 12,
#   'which': 1,
#   'is': 8,
#   ',': 2,
#   'was': 1,
#   '.': 4,
#   'french': 2,
#   'selections': 1,
#   'cork': 1,
#   'oak': 2,
#   'to': 4,
#   'shiraz': 4,
#   'that': 2,
#   'across': 1,
#   'has': 1,
#   'without': 2,
#   'you': 1,
#   'pinot': 2,
#   'in': 4,
#   'everything': 1,
#   'for': 3,
#   'makes': 1,
#   'Rutherglen': 1,
#   'each': 2,
#   'levels': 2,
#   'at': 6,
#   'certified': 1,
#   'riesling': 1,
#   'grapes': 1,
#   'would': 1,
#   'organic': 2,
#   'vanillin': 2,
#   'Riverina': 1,
#   'wine': 2,
#   'McLaren': 1,
#   'simply': 1,
#   'Marlborough': 1,
#   'SA': 1,
#   'meets': 1,
#   'packed': 1,
#   'Clare': 1,
#   'Durif': 1},
#  'English': {'grain': 1},
#  'spirit': {'from': 1, 'was': 1, 'and': 2},
#  'Suffolk': {'and': 1},
#  'Norfolk': {'and': 1},
#  'spring': {'water': 1,
#   'was': 4,
#   'which': 1,
#   'rains': 2,
#   'were': 1,
#   ',': 3,
#   'Vale': 1,
#   'months': 2,
#   'rainfall': 1,
#   '.': 1,
#   'vegetable': 1,
#   'period': 1,
#   'rainfalls': 1,
#   'is': 1,
#   'cuisine': 1,
#   'in': 1,
#   'or': 1,
#   'locked': 2,
#   'day': 1,
#   'and': 1},
#  'water': {'found': 1, '.': 1, '!': 1, 'just': 1},
#  'found': {'in': 3, 'on': 1, 'it': 2, 'the': 1, 'traditionally': 1},
#  'north': {'of': 4, 'facing': 1, 'island': 1, 'Canterbury': 1, 'eastern': 1},
#  'distilled': {'by': 1, 'using': 1, 'and': 1},
#  'master': {'distiller': 1, 'Mobbs': 2},
#  'distiller': {'Charles': 1},
#  'Charles': {'Maxwell': 1},
#  'Maxwell': {',': 1},
#  'gin': {'presents': 1, 'cured': 1, 'is': 1},
#  'presents': {'itself': 1, 'with': 2},
#  'itself': {'in': 1,
#   'places': 1,
#   'together': 1,
#   'with': 1,
#   '.': 1,
#   'so': 1,
#   'well': 2,
#   '-': 2},
#  'luminous': {',': 1, 'yellow': 1, 'litchi': 1},
#  'blue': {'aquamarine': 1,
#   'eyed': 2,
#   'berry': 1,
#   'fruits': 2,
#   'and': 3,
#   'berries': 2,
#   'ocean': 1},
#  'aquamarine': {'colour': 1},
#  'overall': {'with': 1,
#   'savoury': 1,
#   'minerality': 1,
#   'balance': 2,
#   'an': 1,
#   'sub-plot': 1},
#  'sensual': {'finish': 1},
#  'Chook': {'shiraz': 1, 'Macedon': 1},
#  '2014': {'displays': 7,
#   'is': 14,
#   'offers': 1,
#   'has': 3,
#   'shiraz': 1,
#   'originates': 2,
#   ',': 3,
#   'aromas': 1,
#   'exhibits': 1,
#   'Barossa': 1,
#   'pale': 1},
#  'vanillin': {'spice': 1, 'and': 1, 'oak': 6, 'cedar': 3, 'notes': 1},
#  'Buckshot': {'vineyard': 1},
#  'Heathcote': {'shiraz': 7,
#   'region': 2,
#   '.': 1,
#   'where': 1,
#   'site': 1,
#   ',': 1,
#   'in': 1},
#  'opaque': {'black': 4, 'violet': 1},
#  'attractive': {'bouquet': 1,
#   'style': 1,
#   'ripe': 1,
#   'sweet': 1,
#   'nose': 1,
#   'and': 1,
#   'oak': 1},
#  'possesses': {'generous': 1},
#  'generous': {'blackberry': 1,
#   'flavours': 2,
#   'notes': 1,
#   'plum': 1,
#   'weight': 1,
#   'with': 1,
#   ',': 1,
#   'and': 3,
#   'perfumed': 1,
#   'palate': 3,
#   'finish': 2,
#   'mid-palate': 1,
#   'fruit': 1,
#   'characters': 1,
#   'in': 1,
#   'flavour': 1,
#   'hint': 1,
#   '.': 3,
#   'shiraz': 1,
#   'on': 2,
#   'chalky': 1,
#   'length': 1,
#   'layers': 1},
#  'velvet': {'smooth': 1, 'and': 1, 'glove': 2},
#  'aftertaste': {'of': 6, '.': 1},
#  'flying': {'fish': 3, 'out': 1, 'off': 1},
#  'Cove': {'Wildberry': 3},
#  'Wildberry': {'reserve': 3},
#  'reserve': {'cabernet': 2,
#   'chardonnay': 5,
#   'pinot': 1,
#   'wines': 1,
#   'shiraz': 2,
#   'wine': 1,
#   'range': 3,
#   'ties': 1,
#   'McLaren': 1,
#   'label': 1,
#   'Willyabrup': 1,
#   'Margaret': 1},
#  'originates': {'from': 21},
#  'Margaret': {'river': 45, "River's": 2, 'River’s': 1, ',': 1},
#  'river': {'region': 6,
#   'valley': 3,
#   'classic': 1,
#   '.': 7,
#   '9th': 1,
#   ',': 6,
#   'chardonnay': 4,
#   'enthusiast': 1,
#   'go': 1,
#   'is': 1,
#   'and': 1,
#   'cabernet': 1,
#   'red': 1,
#   'shiraz': 2,
#   'masterpiece': 1,
#   'malbec': 1,
#   '-': 2,
#   'juice': 1,
#   'gold': 2,
#   'gem': 2,
#   'which': 1,
#   'has': 1,
#   ';': 1,
#   'sites': 1,
#   'wine': 1,
#   'sell': 1,
#   'of': 1,
#   'blend': 1,
#   'ensure': 1,
#   'hero': 1},
#  'region': {'of': 32,
#   ',': 9,
#   'on': 2,
#   'in': 5,
#   '.': 18,
#   'with': 1,
#   'that': 4,
#   'then': 1,
#   'and': 4,
#   'work': 1,
#   'would': 1,
#   '!': 1,
#   'inside': 1,
#   'has': 5,
#   'which': 3,
#   'syrah': 1,
#   'chardonnay': 1,
#   'is': 3,
#   'for': 4,
#   'but': 1,
#   'south': 2,
#   'right': 1,
#   'adds': 1,
#   'all': 1,
#   'usually': 1,
#   'it': 1,
#   'normally': 1,
#   'lies': 1,
#   'the': 1},
#  'Western': {'Australia': 4},
#  'Australia': {'.': 27,
#   'set': 1,
#   'might': 1,
#   'day': 1,
#   'can': 1,
#   ',': 4,
#   'and': 1,
#   'as': 3,
#   'currently': 1,
#   'it': 1},
#  'mulberry': {',': 8, 'fruits': 2, 'and': 5},
#  'combination': {',': 1, 'of': 11, 'translates': 1},
#  'Jacqueline': {'brut': 1, 'into': 1},
#  'de': {'Blanc': 1,
#   'Bortoli': 12,
#   'Ruinart': 1,
#   'Blancs': 5,
#   'Lascombes': 1,
#   "Blancs'": 1},
#  'France': {'.': 6, 'often': 1, ',': 3},
#  'ideal': {'for': 2,
#   'mild': 1,
#   'aperitif': 1,
#   'welcome': 1,
#   'wine': 1,
#   'profile': 1,
#   'conditions': 1,
#   'to': 1},
#  'festive': {'touch': 1, 'evenings': 1},
#  'occasion': {'.': 2,
#   'like': 2,
#   'with': 2,
#   'or': 2,
#   ',': 2,
#   'when': 1,
#   'sing': 1},
#  'bubbles': {'are': 1, '.': 6, 'on': 1, 'for': 1, '!': 1, 'and': 1, 'is': 1},
#  'companion': {'for': 2, '2011': 1, ',': 1},
#  'give': {'cocktails': 1,
#   'this': 4,
#   'it': 4,
#   'structure': 2,
#   'the': 5,
#   'you': 1,
#   'amazing': 1,
#   'a': 1},
#  'cocktails': {'a': 1, 'and': 1, ',': 1},
#  'delightful': {'fizz': 1,
#   'shiraz': 1,
#   'fruit': 1,
#   'to': 1,
#   'spice': 2,
#   'savoury': 1,
#   'eternity': 2,
#   'sip': 1,
#   'parcel': 2,
#   'berry': 1,
#   'satsuma': 1,
#   'with': 2},
#  'fizz': {'.': 2, "won't": 1, 'as': 1},
#  'gold': {',': 2,
#   'and': 2,
#   'in': 3,
#   'Chook': 1,
#   'hue': 1,
#   '.': 1,
#   'with': 1,
#   'each': 2,
#   'medals': 2},
#  'fruity': {'with': 4,
#   'hints': 1,
#   'in': 1,
#   'on': 1,
#   ',': 3,
#   'esters': 1,
#   'notes': 1,
#   'nose': 1,
#   'wine': 1,
#   'texture': 1,
#   'white': 1,
#   'yet': 1,
#   'stereotype': 1,
#   'and': 2,
#   'goodness': 1,
#   'sauvignon': 1,
#   'mid-palate': 1,
#   'flavour': 2},
#  'palagte': {'with': 1},
#  'floral': {'notes': 14,
#   ',': 2,
#   'aromatics': 1,
#   'flavours': 1,
#   'undertone': 1,
#   'aromas': 5,
#   'nose': 1,
#   'Viognier': 1,
#   'and': 9,
#   'tones': 1,
#   'lift': 3,
#   'bouquet': 1,
#   'spice': 1,
#   'tropical': 1,
#   'hints': 1,
#   'hints…are': 2,
#   'perfume': 1,
#   'jasmine': 1,
#   'note': 1},
#  'Chivas': {'Regal': 1},
#  'Regal': {'12': 1},
#  'year': {'old': 13,
#   'since': 1,
#   '.': 12,
#   'which': 1,
#   'dry': 1,
#   'in': 7,
#   'nominee': 1,
#   '2005': 2,
#   '2001': 1,
#   ',': 5,
#   'out': 4,
#   'and': 1,
#   'brings': 1,
#   '!': 1,
#   'for': 3,
#   'to': 3,
#   'organic': 2,
#   'with': 1,
#   'round': 1,
#   'at': 1,
#   'process)': 1,
#   'so': 2,
#   'on': 1,
#   "it's": 1},
#  'old': {'Scotch': 1,
#   'Whisky': 1,
#   'Adam': 1,
#   ',': 4,
#   'Block': 1,
#   'french': 6,
#   'fashioned': 2,
#   'vines': 7,
#   'for': 1,
#   'vine': 2,
#   'oak': 2,
#   'school': 4,
#   'style': 1,
#   'sweet': 1,
#   'favourites': 1,
#   'over': 2,
#   'Tawny': 1,
#   '.': 1,
#   'buttery': 2,
#   'world': 4},
#  'Whisky': {'from': 1, 'has': 1, 'is': 1},
#  'Scottish': {'Highlands': 1},
#  'Highlands': {',': 1},
#  'resulted': {'in': 13},
#  'honey': {'and': 4, ',': 5, '.': 2, 'blossom': 1, 'while': 1},
#  'radiant': {'amber': 1, 'bouquet': 1},
#  'amber': {'colour': 1, 'hues': 1},
#  'infusion': {'of': 1},
#  'herbs': {',': 3,
#   'followed': 1,
#   '.': 3,
#   'and': 10,
#   'on': 1,
#   'lingering': 1,
#   'all': 1},
#  'orchard': {'fruits': 1, 'fruit': 1, 'in': 1},
#  'apples': {',': 9, 'flavour': 1, 'and': 4, 'with': 1, '&': 1},
#  'Babich': {'Marlborough': 1},
#  'Marlborough': {'sauvignon': 3,
#   '.': 4,
#   'region': 2,
#   'NZ': 4,
#   'need': 1,
#   'means': 1,
#   'is': 1,
#   'synonymous': 1,
#   'lovers': 1,
#   'has': 1,
#   'fruit': 1,
#   'drop': 1,
#   ',': 1},
#  'make': {'this': 5,
#   'sure': 2,
#   'up': 2,
#   'the': 6,
#   'cool': 1,
#   'it': 8,
#   'itself': 1,
#   'you': 4,
#   'his': 2,
#   '-': 1,
#   'a': 2,
#   'each': 1,
#   'no': 1,
#   'grapes': 1,
#   'wines': 1,
#   'any': 2,
#   'your': 3,
#   'Italian': 1,
#   'for': 1},
#  'treat': {'to': 2,
#   '.': 3,
#   'yourself': 3,
#   'themselves': 1,
#   ',': 2,
#   'for': 3,
#   'of': 1,
#   'is': 2,
#   'from': 6,
#   'when': 1,
#   'with': 3,
#   'on': 1,
#   'grapes': 1,
#   'and': 1,
#   'your': 1,
#   'you': 1},
#  'seafood': {';': 1,
#   '.': 5,
#   'and': 4,
#   'or': 4,
#   ',': 5,
#   'stir-fry’s': 1,
#   'dishes': 1,
#   'with': 1},
#  'Farr': {'Viognier': 1},
#  'Viognier': {'2012': 2,
#   'aromatics': 1,
#   'has': 1,
#   '-': 1,
#   'varietals': 1,
#   'gives': 1,
#   'Rousanne': 1,
#   'is': 2,
#   'grapes': 1,
#   'was': 1,
#   '10%': 1,
#   'from': 1,
#   ',': 1,
#   '.': 1},
#  'apricot': {'and': 4,
#   'skin': 1,
#   ',': 3,
#   'appear': 1,
#   'followed': 1,
#   '.': 1,
#   'will': 1},
#  'remains': {'just': 1, 'in': 1},
#  'skin': {'on': 1,
#   ',': 3,
#   'and': 1,
#   'phenolics': 1,
#   'contact': 4,
#   'fermented': 1,
#   'ferment': 1},
#  'Bortoli': {'Yarra': 2,
#   'Bella': 1,
#   'Prosecco': 1,
#   'windy': 2,
#   'Woodfired': 1,
#   'PHI': 2,
#   'BellaRiva': 1,
#   'Rococo': 1,
#   'single': 1},
#  'Villages': {'sauvignon': 1, 'chardonnay': 1},
#  'edges': {'.': 5},
#  'nutty': {'edge': 1,
#   'savoury': 1,
#   'oak': 3,
#   'characteristics': 1,
#   'spice': 1,
#   'undertone': 1,
#   'nuance': 1,
#   ',': 1},
#  'Panko': {'crumbed': 1},
#  'crumbed': {'whiting': 1},
#  'whiting': {'tails': 1, 'and': 1},
#  'tails': {'.': 1},
#  'Bremerton': {'old': 1},
#  'Adam': {'shiraz': 1,
#   'has': 4,
#   'sourced': 2,
#   'Barton': 3,
#   'dances': 2,
#   'is': 2,
#   'openly': 1},
#  'Langhorne': {'Creek': 3},
#  'integrated': {'fruit': 2,
#   'cedary': 1,
#   'acid': 1,
#   'creamy': 1,
#   'into': 3,
#   'this': 1,
#   'juicy': 1,
#   'oak': 2,
#   'fine': 1,
#   'tannins': 1,
#   'Naked': 2,
#   'malts': 1},
#  'Bella': {'Riva': 1, 'and': 1},
#  'Riva': {'Sangiovese': 1},
#  'Sangiovese': {'King': 1,
#   'rosé': 1,
#   '2013': 1,
#   'and': 1,
#   '.': 1,
#   'from': 1,
#   'grape': 1,
#   'is': 2,
#   'brings': 1},
#  'King': {'valley': 4, 'of': 6},
#  'pink': {'in': 1,
#   'wine': 1,
#   'florals': 1,
#   'with': 2,
#   'grapefruit': 2,
#   'color': 1,
#   'hue': 1,
#   'mousse': 1,
#   'colour': 2,
#   'Lady': 1,
#   'blush': 1},
#  'morello': {'cherry': 3, 'cherries': 2},
#  'nougat': {'.': 3, ',': 1, 'and': 2},
#  'cured': {'salmon': 1, 'meat': 1, 'meats': 1},
#  'Tapanappa': {'Piccadilly': 1, 'Whalebone': 4, 'Fleurieu': 1},
#  'Piccadilly': {'valley': 1},
#  'array': {'of': 17},
#  'crisp': {'and': 15,
#   ',': 15,
#   'dry': 2,
#   'in': 1,
#   'acidity': 8,
#   '.': 1,
#   'sweet': 1,
#   'with': 3,
#   'finish': 7,
#   'acid': 1,
#   'pears': 1,
#   'apple': 1,
#   'fruit': 1,
#   'yet': 1,
#   'line': 1,
#   'lemongrass': 1,
#   'refreshment': 1},
#  'pristine': {'aromas': 1,
#   'and': 2,
#   'juice': 1,
#   'dark': 1,
#   'aroma': 1,
#   'flavours': 1,
#   'fruit': 7,
#   'bunches': 1,
#   'fruit-driven': 1,
#   'single': 1,
#   'Adelaide': 1,
#   'quality': 3,
#   'NSW': 2},
#  'meringue': {'and': 1},
#  'terrific': {'length': 1, ',': 1, 'complexity': 1, 'value': 1},
#  '92': {'points': 2},
#  'Huon': {'Hooke': 5, 'Hooke97': 1},
#  'Hooke': {'95': 1, 'Penfolds': 1, 'Kangarilla': 1, 'the': 1, 'Tokar': 1},
#  '95': {'points': 2},
#  'Tyson': {'Stelzer': 4, 'Stelzer94': 1},
#  'Stelzer': {'deep': 1, 'Penfolds': 1, 'the': 1, 'Mollydooker': 1},
#  'raspberry': {'and': 16,
#   'lollies': 1,
#   '.': 3,
#   'jelly': 1,
#   ',': 14,
#   'with': 1,
#   'that': 1,
#   'licorice': 1,
#   'notes': 1,
#   'will': 1},
#  'punctuated': {'by': 1},
#  'big': {'velvety': 1,
#   ',': 5,
#   'yet': 1,
#   'wines': 1,
#   'red': 2,
#   'flavour': 2,
#   'wine': 1,
#   'earthenware': 1,
#   'thanks': 1,
#   'thing': 1,
#   'dreams': 2,
#   'smile': 1,
#   'ferment': 1,
#   'scale': 1,
#   'bold': 2},
#  '66%': {'grenache': 1},
#  'grenache': {',': 5,
#   'blend': 1,
#   'shiraz': 2,
#   'wine': 1,
#   'is': 2,
#   '–': 1,
#   'has': 1,
#   'generally': 1,
#   'and': 2,
#   'by': 1,
#   'Mourvèdre': 1,
#   'Mourvédre': 1,
#   'at': 1,
#   '-': 1},
#  '26%': {'mataro': 1},
#  'mataro': {'and': 2,
#   '.': 2,
#   '2014': 1,
#   'have': 1,
#   '!': 1,
#   'is': 1,
#   'grapes': 1},
#  '8%': {'shiraz': 1},
#  'grapes': {'grown': 1,
#   'being': 2,
#   'could': 1,
#   'were': 21,
#   'and': 6,
#   'are': 9,
#   'used': 1,
#   'harvested': 1,
#   'meld': 2,
#   '.': 11,
#   'from': 15,
#   'sourced': 2,
#   'flavour': 1,
#   'with': 1,
#   'for': 5,
#   'of': 3,
#   ',': 4,
#   'at': 1,
#   'that': 1,
#   'has': 3,
#   'to': 6,
#   "aren't": 1,
#   'will': 1,
#   'possible': 1,
#   'sing': 1,
#   'before': 2,
#   'form': 2,
#   'like': 1,
#   'gets': 1,
#   'on': 2,
#   'creates': 1,
#   'in': 1,
#   'do': 1,
#   'among': 1,
#   'natural': 1,
#   'off': 1,
#   'along': 1,
#   'give': 1,
#   'gift': 1,
#   'is': 1,
#   'started': 1,
#   'while': 2,
#   'back': 1,
#   'full': 1},
#  'grown': {'in': 8,
#   'and': 8,
#   'red': 1,
#   'on': 3,
#   'no': 1,
#   ',': 2,
#   'from': 2,
#   'at': 1,
#   'vines': 2,
#   'overlooking': 1,
#   'by': 1,
#   'carrots': 1,
#   'shiraz': 1,
#   'dramatically': 1,
#   'vineyard': 1,
#   'provide': 1,
#   'grapes': 1},
#  'Barossa': {'valley': 19,
#   'Lutheran': 1,
#   'Toddler': 2,
#   'winemaker': 1,
#   'shiraz': 4,
#   'vintage': 1,
#   'legend': 1,
#   '.': 1,
#   'red': 1,
#   'Valley’s': 1,
#   'character': 1,
#   'winemaking': 1,
#   'is': 2,
#   'GSM': 2,
#   'ranges': 2},
#  'harvest': {'date:': 1,
#   'continued': 1,
#   'the': 1,
#   'in': 2,
#   '.': 4,
#   'of': 1,
#   'was': 3},
#  'date:': {'9': 1, '5': 1, '7': 1},
#  '9': {'March-16': 1, 'g/LpH:': 1, '.': 2, 'months': 2},
#  'March-16': {'April': 1},
#  'April': {'|': 1,
#   '.': 2,
#   '2011Alc/Vol:': 1,
#   'to': 1,
#   'temperatures': 1,
#   'saw': 1},
#  '|': {'Alcohol:': 1, 'pH:': 1, 'acidity:': 1},
#  'Alcohol:': {'14': 1},
#  '14': {'.': 8, 'months': 2, 'March': 1},
#  '5%': {'|': 1,
#   '::': 1,
#   'older': 1,
#   'Ed': 1,
#   '3': 1,
#   'alcohol': 1,
#   'and': 1,
#   ',': 1},
#  'pH:': {'3': 4},
#  '3': {'.': 12,
#   'shiraz': 2,
#   'characters': 1,
#   'drops': 1,
#   'years': 1,
#   'varieties': 1,
#   'months': 3},
#  '45': {'|': 1, '7': 1},
#  'acidity:': {'6': 2, '5': 1},
#  '3g/LGrenache': {',': 1},
#  'vinified': {'separately': 2, 'in': 1},
#  'separately': {'.': 2,
#   'while': 1,
#   'to': 2,
#   'and': 2,
#   'but': 1,
#   ',': 2,
#   'in': 3,
#   'by': 1},
#  'matured': {'in': 13, 'for': 6, 'on': 6, 'separately': 1, 'oak': 1},
#  'seasoned': {'french': 5, 'oak': 1},
#  'hogsheads': {'for': 3, ',': 1, '.': 1},
#  'months': {'prior': 1,
#   'of': 3,
#   'in': 13,
#   'at': 1,
#   '.': 9,
#   'or': 1,
#   'and': 1,
#   ',': 7,
#   '-': 4,
#   'to': 5,
#   'until': 1,
#   'for': 1,
#   'before': 2,
#   '?': 1,
#   'this': 3,
#   'time': 1},
#  'prior': {'to': 11},
#  'blending': {'and': 1,
#   ',': 2,
#   'of': 2,
#   'chardonnay': 1,
#   'at': 1,
#   'portions': 1,
#   'warm': 1,
#   'these': 1,
#   'red': 1},
#  'bottling': {'.': 7, 'this': 1},
#  'named': {'as': 1, 'after': 2, '2017': 1, 'this': 1},
#  'tribute': {'to': 1},
#  'early': {'Barossa': 1,
#   'summer': 2,
#   'January': 1,
#   'autumn': 1,
#   'March': 1,
#   'April': 1,
#   'December': 1,
#   ',': 1,
#   'drinking': 1,
#   'settlers': 1,
#   'canopy': 1,
#   'start': 1,
#   'opening': 1,
#   'pick': 1,
#   'ripening': 1,
#   'to': 4,
#   'from': 2,
#   'harvest': 2,
#   "80's": 1,
#   'morning': 1},
#  'Lutheran': {'pioneers': 1},
#  'pioneers': {',': 1},
#  'whom': {'carried': 1},
#  'carried': {'the': 1, 'by': 1, 'on': 1},
#  'name': {'of': 5, 'in': 1, 'has': 1},
#  'Johann': {'.': 1},
#  'their': {'toil': 1,
#   'prudent': 1,
#   'vineyard': 1,
#   'garden': 1,
#   'heritage': 1,
#   'honey': 1,
#   'youth': 1,
#   'children': 1,
#   'way': 1,
#   'little': 1,
#   'distinctively': 1,
#   'first': 4,
#   'JSM': 1,
#   'passion': 1,
#   'magic': 1,
#   'wine': 4,
#   'ultimate': 2,
#   'precious': 1,
#   'daughter': 1,
#   'home': 1,
#   'talent': 1,
#   'offspring': 1,
#   'brand': 1,
#   'own': 1,
#   'aim': 1,
#   'approach': 4,
#   'decades': 2,
#   'estate': 2,
#   'woody': 1,
#   'craft': 3,
#   'top': 2,
#   'next': 2,
#   'luscious': 1,
#   'vinous': 1,
#   'potential': 1,
#   'location': 1,
#   'Uncharted': 1,
#   'work': 1,
#   'hands': 1,
#   'huge': 2,
#   'best': 3,
#   'beloved': 4,
#   'second': 2,
#   'head': 1,
#   'heart': 2,
#   'goal': 3,
#   'incredible': 2,
#   'skins': 1,
#   'team': 1,
#   'vines': 1,
#   'white': 2,
#   'outstanding': 1,
#   'personal': 1,
#   'Clare': 2,
#   'fingertips': 1,
#   'dose': 1,
#   'dream': 1,
#   'Angel': 1,
#   'lips': 1,
#   'shiraz': 1,
#   'debut': 1,
#   'organic': 1,
#   'crowd': 1,
#   'toe': 1,
#   'grapes': 1,
#   'door': 1,
#   'latest': 1,
#   'dial': 1,
#   'winemaking': 1,
#   'Boy': 1},
#  'toil': {',': 1},
#  'perseverance': {'and': 1},
#  'conservatism': {'in': 1},
#  'hardship': {'has': 1},
#  'meant': {'that': 3, 'meticulous': 1},
#  'generations': {'that': 1, 'of': 5},
#  'rejoiced': {'in': 1},
#  'riches': {'of': 1, 'on': 1},
#  'prudent': {'efforts': 1},
#  ...}

# %%
fname = '%s/dataOne.json' % dataDir
with open(fname,'w') as f:
    json.dump(dataOne,f)

# %%
# data is a dictionary
# the keys are what we are choosing
# the values are the weights
def weightedRandom(dist):
    entries = list(dist.keys())
    assert(len(entries) > 0)
    probabilities = [dist[e] for e in entries]
    scale = sum(probabilities)
    probabilities = [float(p)/scale for p in probabilities]
    draw = choice(range(len(entries)), 1, p=probabilities)[0]
    return(entries[draw])

# %%
def generateSentenceOne():
    word = weightedRandom(dataOne['']) # first word
    words = [word]
    while word not in '?!.;':
        prevWord = words[-1]
        word = weightedRandom(dataOne[prevWord])
        words.append(word)
    
    sentence = ''
    for word in words:
        if sentence == '':
            if len(word) == 1:
                sentence = word.upper()
            else:
                sentence = word[0].upper() + word[1:]
        else:
            if (word not in '-.,?;!'):
                sentence += ' '
            sentence += word
    if len(sentence) < 10:
        sentence = generateSentenceOne()
    return(sentence)

# %%
[generateSentenceOne() for _ in range(10)]
# Out:
# ['Anna and shiraz Durif grapes sourced from the structure, good colour density.',
#  "It's gone.",
#  'Bright crimson with dark cherry with a world year brings savoury spice.',
#  'This wine extremely rare example of the perfect to the palate and a medium body and radiant amber hues.',
#  'At Fraser Gallop estate cabernet shiraz, flavour left high in colour.',
#  'Ahhh, intrinsic flavour.',
#  'Like us!), and palate is seriously approachable now.',
#  'The Adelaide region on the Barossa valley estate chardonnay with our shelves!',
#  'Packed in cooler sites of a very complex, fresh fruits and bramble and the habitat brut is a beautiful, vegetable and a super generous shiraz;',
#  'Pizzini merlot 2009 St George vineyard grapes were small portion of red colour with refinement, dark in other house of the gentle crush and spicy home being one of liquid gold with dark fruited palate is your first for under $20 anywhere, and more importantly, extending to get your door direct from sustainably farmed vineyards in central ranges offers an asian cuisine;']

# %% [markdown]
# # N Layer chain

# %%
numLayers = 2
assert(numLayers > 0)

# %%
# split allTextSplit into a list of sentences, where each sentence is a list of words
sentences = [[]]
for word in allTextSplit:
    sentences[-1].append(word)
    if word in '?!.;-':
        sentences.append([])

# %%
dataNStart = {}
dataN = {}
solo = 0
many = 0
for sentence in sentences:
    if len(sentence) > numLayers:
        # get the start of the sentence
        firstN = tuple(sentence[0:numLayers])
        if firstN in dataNStart:
            dataNStart[firstN] += 1
        else:
            dataNStart[firstN] = 1

        # now the rest
        for i in range(numLayers,len(sentence)):
            thisWord = sentence[i]
            prevWords = tuple(sentence[i-numLayers:i])
            if prevWords not in dataN:
                dataN[prevWords] = {thisWord:1}
            elif thisWord not in dataN[prevWords]:
                dataN[prevWords][thisWord] = 1
                solo += 1
            else:
                dataN[prevWords][thisWord] += 1
                many += 1


assert(all([type(k) == type((1,2)) for k in dataN.keys()]))
print("solo: %d" % solo)
print("many: %d" % many)
assert(all([k in dataN for k in dataNStart]))
# Out:
# solo: 16970
# many: 15226

# %%
print("Starting")
# This is pretty messy

# I want to remove all words for which filter(word) returns True
# but then I have to remove all paths which lead to only that word
# but then I have to remove all paths which lead to only those paths
# etc.

def filter(word):
    names = ['Ben','James','Tyson','Steve','Andrew','Campbell','Jen','Margaret','Nigel', 'Kim','James-Paul','Gary']
    for name in names:
        if word in [name,name + "'s"]:
            return(True)
    if word.lower() in ['angel',"angel's","angels",'naked']:
        # Naked Wines mentions these a lot
        return(True)
    elif word.lower() in ['points']:
        # wineonline mentions these
        return(True)
    else:
        return(False)

# returns a dict
# {'start':[],'main':{'keys':[],'leafs':{k:[]}},'count':x}
# Where that first list is the list of keys to remove from the start dict
# And the 2nd is the list of keys to remove from the outer level of the main dict
# And the 3rd is the list of keys to remove from the inner level of the main dict
def getToPrune(startData,mainData):
    ret = {}
    ret['start'] = set([words for words in startData if any([filter(word) for word in words]) or words not in mainData])
    ret['count'] = len(ret['start'])
    print("Populated ret[start] with %d" % ret['count'])
    ret['main'] = {'leafs':{},'keys':set()}
    for prevWords in mainData: # a tuple of words
        #print("running getToPrune with prevWords = " + str(prevWords))
        # TODO: check if these leafs exist as keys
        for nextWord in mainData[prevWords]: 
            
            # if this word is in the filter, delete it
            # if choosing this word will give a chain that leads to a dead end, delete it
            newChain = (prevWords + (nextWord,))[1:]
            if filter(nextWord) or ((newChain not in mainData) and (nextWord not in '.!?')):
                if prevWords not in ret['main']['leafs']:
                    ret['main']['leafs'][prevWords] = set([nextWord])
                else:
                    ret['main']['leafs'][prevWords].add(nextWord)
#                 if filter(nextWord):
#                     print("Incrementing count for mainData[%s][%s] because %s is filtered" % (str(prevWords),nextWord,nextWord))
#                 else:
#                     print("Incrementing count for mainData[%s][%s] because %s a dead end" % (str(prevWords),nextWord,newChain))
                ret['count'] += 1
        
        # if we are about to delete all entries for mainData[prevWords], delete prevWords from mainData
        deletePrevWords = (prevWords in ret['main']['leafs']) and (len(ret['main']['leafs'][prevWords]) == len(mainData[prevWords]))
        
        # if mainData[prevWords] is already empty, delete it
        deletePrevWords |= len(mainData[prevWords]) == 0
        
        if deletePrevWords:
            ret['main']['keys'].add(prevWords)
#             print("Incrementing count for words %s" % str(prevWords))
            ret['count'] += 1
        elif (len(mainData[prevWords]) == 0):
#             print("Incrementing count for words %s" % str(prevWords))
            ret['main']['keys'].add(prevWords)
            ret['count'] += 1
    return(ret)
    
print("Starting pruning")
toPrune = getToPrune(dataNStart,dataN)
# toPrune
while toPrune['count'] > 0:
#     print('pruning (count = %d)' % toPrune['count'])
#     print("pruning %d from start dict" % len(toPrune['start']))
    assert(all([k in dataNStart for k in toPrune['start']]))
    dataNStart = {k:dataNStart[k] for k in dataNStart if k not in toPrune['start']}
    
#     print("pruning %d from main leafs" % sum([len(toPrune['main']['leafs'][k]) for k in toPrune['main']['leafs']]))
    for k in toPrune['main']['leafs']:
        assert(k in dataN)
        assert(all([j in dataN[k] for j in toPrune['main']['leafs'][k]]))
        dataN[k] = {j:dataN[k][j] for j in dataN[k] if j not in toPrune['main']['leafs'][k]}
        
#     print("pruning %d from main keys" % len(toPrune['main']['keys']))
    assert(all([k in dataN for k in toPrune['main']['keys']]))
    dataN = {k:dataN[k] for k in dataN if k not in toPrune['main']['keys']}
    toPrune = getToPrune(dataNStart,dataN)
    
solo = 0
many = 0
for k in dataN:
    if len(dataN[k]) == 1:
        solo += 1
    else:
        many += 1
        
print("Solo: %d" % solo)
print("Many: %d" % many)
    
print("done")
# Out:
# Starting
# Starting pruning
# Populated ret[start] with 0
# Solo: 21558
# Many: 5570
# done

# %%
def capitalise(word):
    if len(word) == 1:
        return(word.upper())
    else:
        return(word[0].upper() + word[1:])

assert(capitalise('a') == 'A')
assert(capitalise('hello') == 'Hello')
assert(capitalise('A') == 'A')
assert(capitalise('Hello') == 'Hello')
    
def generateSentenceMany():
    words = list(weightedRandom(dataNStart))
    while words[-1] not in '!?.':
        weights = dataN[tuple(words[-numLayers:])]
        nextWord = weightedRandom(weights)
        assert(type(nextWord) == type(''))
        words.append(nextWord)
        
    sentence = capitalise(words[0])
    for word in words[1:]:
        if word not in ',.!?;':
            sentence += ' '
        sentence += word
        
    if not (5 < len(words) < 25):
        # bad length, try again
        return(generateSentenceMany())
    else:
        print(words)
        print(sentence)
        print('')
        return(sentence)

[generateSentenceMany() for _ in range(10)]
print('')
# Out:
# ['the', 'harvest', 'was', 'fermented', 'in', 'new', 'french', 'oak', 'and', ',', 'chardonnay', 'and', 'apply', 'their', 'personal', 'flair', 'at', 'every', 'step', 'in', 'the', 'clouds', '.']
# The harvest was fermented in new french oak and, chardonnay and apply their personal flair at every step in the clouds.
#
# ['each', 'glass', 'will', 'deliver', 'the', 'most', 'premium', 'and', 'pristinely', 'sourced', 'chardonnay', 'at', 'incredibly', 'accessible', 'prices', 'for', 'you', '!']
# Each glass will deliver the most premium and pristinely sourced chardonnay at incredibly accessible prices for you!
#
# ['on', 'top', 'of', 'all', ',', 'pinot', 'G', ',', 'and', 'historically', 'one', 'of', 'the', 'wine', 'long', 'and', 'earthy', 'notes', '.']
# On top of all, pinot G, and historically one of the wine long and earthy notes.
#
# ['an', 'impressive', 'inky', 'depth', 'fills', 'your', 'glass', '.']
# An impressive inky depth fills your glass.
#
# ['the', '2009', 'St', 'George', 'vineyard', 'cabernet', 'shiraz', '2016', 'has', 'a', 'sensational', 'balance', 'of', 'purity', 'and', 'a', 'girdle', 'of', 'grainy', 'tannin', '.']
# The 2009 St George vineyard cabernet shiraz 2016 has a sensational balance of purity and a girdle of grainy tannin.
#
# ['Hilltops', 'is', 'a', 'top', 'producer', 'of', 'the', 'fruit', 'always', 'ensures', 'the', 'end', '.']
# Hilltops is a top producer of the fruit always ensures the end.
#
# ["don't", 'miss', 'out', 'on', 'an', 'eastern', 'facing', 'slope', 'packed', 'with', 'rich', 'red', 'and', 'blue', 'berries', 'and', 'french', 'oak', '.']
# Don't miss out on an eastern facing slope packed with rich red and blue berries and french oak.
#
# ['little', 'Yering', 'chardonnay', 'provides', 'all', 'the', 'wonderment', 'the', 'Marlborough', 'is', 'a', 'great', 'potential', 'to', 'cellar', 'for', 'up', 'to', '15', 'years', '.']
# Little Yering chardonnay provides all the wonderment the Marlborough is a great potential to cellar for up to 15 years.
#
# ['this', 'classy', 'gem', 'is', 'perfect', 'for', 'warm', ',', 'elegant', 'palate', 'structure', 'with', 'bold', 'flavours', 'including', 'pear', 'and', 'apples', 'flavour', 'before', 'the', 'mid', 'palate', '.']
# This classy gem is perfect for warm, elegant palate structure with bold flavours including pear and apples flavour before the mid palate.
#
# ['serious', 'depth', 'in', 'this', 'wine', ',', 'throw', 'it', 'in', 'your', 'basket', 'today', '.']
# Serious depth in this wine, throw it in your basket today.
