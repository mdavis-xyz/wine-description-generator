# %%
import certifi
import urllib3
from bs4 import BeautifulSoup as bs
import pprint as pp
import os
from multiprocessing import Pool
import json
from numpy.random import choice
from random import randint
from num2words import num2words
import random

# %% [markdown]
# # Web scraping

# %%
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())

# %%
# define paths for data caching
dataDir = 'data'
if not os.path.exists(dataDir):
    os.makedirs(dataDir)
urlListFName = '%s/urls.txt' % dataDir

# %% [markdown]
# ## wineoneline.com.au

# %%
# initialise web fetching stuff
domain = "http://www.wineonline.com.au"
dataDirThisDomain = dataDir + '/wineonline'
woAllTextFname = '%s/all.txt' % dataDirThisDomain

# %%
# scrape list of wines to get a list of urls to individual wines
if not os.path.exists(urlListFName):
    individualPages = []

    # get list of wine pages
    for wine_type in ['sparkling','white-wine','red-wine','imported']:
        print("Start of wine_type %s" % wine_type)
        page = 0
        while True:
            suffix = '?sort=alphaasc&page=%d' % page
            url = '/'.join([domain,wine_type,suffix])
            r = http.request('GET',url)
            if r.status == 200:
                print("Hit: " + url)
                html = r.data.decode('utf-8')
                soup = bs(html, 'html.parser')
                individualPages += [a.get('href') for a in soup.select('.ProdHeading a')]
                page = page + 1

            else:
                print("end of %s at %d" % (wine_type, page))
                break
    individualPages = list(set(individualPages))
    print("Writing list of urls to %s" % urlListFName)
    with open(urlListFName,'w') as f:
        f.write('\n'.join(individualPages))
else:
    print("Skipping fetching from the search results pages")
print("Reading in from %s" % urlListFName)
with open(urlListFName,'r') as f:
    individualPages = [line.strip() for line in f.read().split('\n') if line.strip() != '']
#individualPages = individualPages[:10] # only some for now
print("done")
# Out:
# Skipping fetching from the search results pages
# Reading in from data/urls.txt
# done

# %%
paths = [url.rstrip('/').split('/')[-1] for url in individualPages]
assert(len(paths) == len(individualPages))
print("done")
# Out:
# done

# %%
# scrape all the wines in the list

def fetchPath(path):
#     print("fetching %s" % url)
    url = domain.rstrip('/') + '/' + path.lstrip('/')
    dirName = '%s/bottles/%s' % (dataDirThisDomain,path)
    if not os.path.exists(dirName):
        os.makedirs(dirName)
    htmlFName = '%s/%s' % (dirName,'html.html')
    if not os.path.exists(htmlFName):
        print("Fetching %s" % url)
        r = http.request('GET',url)
        if r.status == 200:
    #         print("Parsing %s" % url)
            html = r.data.decode('utf-8').replace(u'\xa0', u' ')
            print("Saving to %s" % htmlFName)
            with open(htmlFName,'w') as f:
                f.write(html)
        else:
            print("Error, status %d for url %s" % (r.status,url))
            return([])
    else:
        print("Hit cache for %s" % htmlFName)
    with open(htmlFName,'r') as f:
        html = f.read()
    return(html)
    

if not os.path.exists(woAllTextFname):
    with Pool(20) as p:
        htmls = p.map(fetchPath,paths)
    print("done")
else:
    print("Skipping, because I'll read from cache")
# Out:
# Fetching http://www.wineonline.com.au/terre-a-terre-cabernet-sauvignon-2012
# Fetching http://www.wineonline.com.au/zema-estate-coonawarra-cabernet-sauvignon-2012
# Fetching http://www.wineonline.com.au/paxton-tempranillo-2016
# Fetching http://www.wineonline.com.au/r-de-ruinart
# Fetching http://www.wineonline.com.au/de-bortoli-yarra-valley-villages-chardonnay-2015
# Saving to data/wineonline/bottles/penfolds-bin-150-shiraz-2014/html.html
# Fetching http://www.wineonline.com.au/wynns-black-label-cabernet-sauvignon-2013
# Saving to data/wineonline/bottles/the-habitat-chardonnay-2015/html.html
# Saving to data/wineonline/bottles/deakin-estate-azahara-sparkling-moscato-nv/html.html
# Fetching http://www.wineonline.com.au/smirnoff-red-label-vodka-700ml
# Saving to data/wineonline/bottles/glaetzer-anaperenna-shiraz-cabernet-2012/html.html
# Fetching http://www.wineonline.com.au/penfolds-bin-389-cabernet-shiraz-2014
# Saving to data/wineonline/bottles/fox-creek-jsm-2013/html.html
# Saving to data/wineonline/bottles/xanadu-reserve-chardonnay-2014/html.html
# Saving to data/wineonline/bottles/hewitson-bashams-beach-tempranillo-2012/html.html
# Saving to data/wineonline/bottles/giant-steps-yarra-valley-pinot-noir-2016/html.html
# Fetching http://www.wineonline.com.au/rob-dolan-true-colours-dry-rose-2016
# Saving to data/wineonline/bottles/chateau-chevalier-de-lascombes-2007-aoc-margaux/html.html
# Saving to data/wineonline/bottles/de-bortoli-bella-riva-sangiovese-2013/html.html
# Saving to data/wineonline/bottles/moet-chandon-imperial-rose/html.html
# Fetching http://www.wineonline.com.au/shadowfax-single-vineyard-geelong-semillon-2010
# Saving to data/wineonline/bottles/wynns-black-label-cabernet-sauvignon-2013/html.html
# Fetching http://www.wineonline.com.au/bombay-sapphire-london-dry-gin-700ml
# Saving to data/wineonline/bottles/smirnoff-red-label-vodka-700ml/html.html
# Fetching http://www.wineonline.com.au/port-phillip-estate-salasso-rose-2017
# Saving to data/wineonline/bottles/penfolds-bin-389-cabernet-shiraz-2014/html.html
# Saving to data/wineonline/bottles/rob-dolan-true-colours-chardonnay-2015/html.html
# Fetching http://www.wineonline.com.au/ninth-island-pinot-grigio-2017
# Saving to data/wineonline/bottles/shadowfax-single-vineyard-geelong-semillon-2010/html.html
# Saving to data/wineonline/bottles/rob-dolan-true-colours-dry-rose-2016/html.html
# Fetching http://www.wineonline.com.au/paul-osicka-heathcote-shiraz-2011
# Saving to data/wineonline/bottles/bombay-sapphire-london-dry-gin-700ml/html.html
# Saving to data/wineonline/bottles/port-phillip-estate-salasso-rose-2017/html.html
# Saving to data/wineonline/bottles/paul-osicka-heathcote-shiraz-2011/html.html
# Saving to data/wineonline/bottles/ninth-island-pinot-grigio-2017/html.html
# Fetching http://www.wineonline.com.au/ferrari-brut-nv
# Saving to data/wineonline/bottles/ferrari-brut-nv/html.html
# done

# %%
if not os.path.exists(woAllTextFname):
    paras = []
    soups = [bs(html) for html in htmls]
    for soup in soups:
        print('next soup')
        paras += soup.select('#ProductDescription p')

    print("done")
else:
    print("Skipping, because I'll read from cache")
# Out:
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# next soup
# done

# %%
if not os.path.exists(woAllTextFname):
    for para in paras:
        for tag in ['span','strong','p']:
            for el in para.find_all(tag):
                if el.string:
                    num_words = len(el.string.replace('\n',' ').split(' '))
                    if num_words < 15:
                        el.string.replace_with('')
else:
    print("Skipping, because I'll read from cache")

# %%
if not os.path.exists(woAllTextFname):
    text = '\n'.join([para.get_text() for para in paras]).replace(u'\xa0',' ')
    for c in '.?!':
        text = text.replace(c,c + ' ').replace(c + '  ',c + ' ')
        
        # hard code fix for their typo
        text = text.replace("tinges and aroma's of stone fruits","tinges and aromas of stone fruits")
        text = text.replace("maturationaromas","aromas")
        text = text.replace("::"," ")
        text = text.replace("MorganHarvested",'Morgan Harvested')
    with open(woAllTextFname,'w') as f:
        f.write(text)

with open(woAllTextFname,'r') as f:
    allTextWO = f.read()

# %% [markdown]
# ## nakedwines.com.au

# %%
# found the number 210 through trial and error
# bigger number means more results per page
# but their crappy site fails when you enter a number too big (e.g. 210)
domain = 'https://www.nakedwines.com.au'

dataDirThisDomain = dataDir + '/nakedwines'

# %%
def getSearchResults(searchPage):
    url = domain + "/wines/index?searchText=&sortWines=descprice&pageSize=20&view=Wines&layoutType=card&allWines=true&pageNum=%d" % searchPage
    print("Fetching " + url)
    r = http.request('GET',url)
    assert(r.status == 200)
    print("Hit: " + url)
    html = r.data.decode('utf-8')
    soup = bs(html, 'html.parser')
    links = [a.get('href') for a in soup.select('a.card__header')]
    print("Found %d results for searchPage %d" % (len(links),searchPage))
    return(links)



if not os.path.exists(dataDirThisDomain):
    os.makedirs(dataDirThisDomain)
fname = '%s/paths.txt' % dataDirThisDomain

if not os.path.exists(fname):
    print("No cache found, fetching from search results on " + domain)
    searchPage = 0
    results = getSearchResults(searchPage)
    individualPages = results
    while len(results) > 0:
        searchPage += 1
        results = getSearchResults(searchPage)
        individualPages += results
    with open(fname,'w') as f:
        f.write('\n'.join(individualPages))
    # write and then read back from file
    # to make sure we wrote correctly

print("Reading urls from cache")
with open(fname,'r') as f:
    individualPages = [x.strip() for x in f.read().split('\n') if x.strip() != '']
    

print("Using urls:")
print('\n'.join(individualPages[:3] + ['...'])) 
print("Discovered %d individual pages" % len(individualPages))
# Out:
# Reading urls from cache
# Using urls:
# /products/karriview-pinot-noir-2016
# /products/sorby-adams-small-barrel-barossa-shiraz-2016
# /products/sam-plunkett-single-vineyard-series-gentle-annie-shiraz-2017
# ...
# Discovered 301 individual pages

# %%
def fetchPath(path):
    url = domain + path
    print("Fetching " + url)
    r = http.request('GET',url)
    assert(r.status == 200)
    print("Hit: " + url)
    html = r.data.decode('utf-8')
    fname = dataDirThisDomain.rstrip('/') + '/' + path.lstrip('/') + '.html'
    directory = '/'.join(fname.split('/')[:-1])
    if not os.path.exists(directory):
        os.makedirs(directory)
    with open(fname,'w') as f:
        f.write(html)
    soup = bs(html, 'html.parser')
    textEls = soup.find(id="tab-tick")
    assert(textEls)
    text = textEls.get_text().replace(u'\xa0',' ').strip()
    for c in '.?!':
        text = text.replace(c,c + ' ').replace(c + '  ',c + ' ')
        
        # hard code fix for a typo
        text = text.replace("punches will above it","punches well above it")
    return(text)

fname = '%s/all.txt' % dataDirThisDomain 
if not os.path.exists(fname):
    print("No cache, fetching")
    with Pool(20) as p:
        texts = p.map(fetchPath,individualPages)
    with open(fname,'w') as f:
        f.write('\n'.join(texts))
else:
    print("hit cache")
    
with open(fname,'r') as f:
    allTextNW = f.read()

    
print("done")
# Out:
# hit cache
# done

# %% [markdown]
# ## combining web scrapes

# %%
allText = allTextWO + '\n' + allTextNW

# %%
# takes in a string, returns an array of words
# where punctuation is a 'word'
def toWords(s):
    s = s.replace('\n',' ').replace('\t',' ')
    for c in '!?.;$':
        s = s.replace(c,c+' ').replace(c + '  ',c + ' ')
    s = s.replace('%',' %') # I want to split off the percent, so I can treat numbers differently
    
    # some text is like
    # Here is (something in backets)No space
    for chars in ['()','[]','{}']:
        s = s.replace(chars[0],chars[0] + ' ').replace(chars[1],chars[1] + ' ')
    words = []
    for chunk in s.split(' '):
        chunk = chunk.lstrip('([{\'“').rstrip(')]}“').strip('`‘""”').replace('—','-').replace('–','-').replace('’',"'")
        if chunk.strip() != '':
            punctuation = ',.?!;-'
            for p in punctuation:
                if chunk.endswith(p):
                    words.append(chunk[:-1])
                    words.append(p)
            if not(any([chunk.endswith(p) for p in punctuation])):
                words.append(chunk)
              
    # if a word appears uncapitalised once, uncapitalise it always
    wordsS = set(words)
    func = lambda x: x.lower() if x.lower() in wordsS else x
    words = [func(w) for w in words]
    
    # remove quotes like 'this quote'
    func = lambda x: x[:-1] if ((len(x) > 1) and (x[-1] == "'") and (x[-2] != 's')) else x
    assert(func("hello'") == "hello")
    assert(func("Yesterday's") == "Yesterday's")
    assert(func("Shores'") == "Shores'")
    assert(func("!") == "!")
    words = [func(w) for w in words]
    
    words = [w for w in words if w != '']
    
    return(words)

def testToWords():
    s = 'At the dawn'
    expected = ['At','the','dawn']
    actual = toWords(s)
    if expected != actual:
        print("expected: ")
        pp.pprint(expected)
        print("actual: ")
        pp.pprint(actual)
    assert(expected==actual)
    
    s = 'Of a  new  age\n'
    words = ['Of','a','new','age']
    assert(words==toWords(s))
    
    s = 'At the dawn, of  a\nnew \n age!'
    expected = ['At','the','dawn',',','of','a','new','age','!']
    actual = toWords(s)
    if expected != actual:
        print("expected: ")
        pp.pprint(expected)
        print("actual: ")
        pp.pprint(actual)
    assert(expected==actual)
    
    s = 'Here is here'
    words = ['here','is','here']
    assert(words==toWords(s))
    
    s = 'Here is (bracket stuff)'
    words = ['Here','is','bracket','stuff']
    if words != toWords(s):
        print(toWords(s))
    assert(words==toWords(s))
    
    
    s = 'Here is (bracket stuff!)'
    words = ['Here','is','bracket','stuff','!']
    if words != toWords(s):
        print(toWords(s))
    assert(words==toWords(s))
    
    s = 'Here is "a quote"'
    words = ['Here','is','a','quote']
    assert(words==toWords(s))
    
    s = "Ha! That's funny"
    words = ['Ha','!',"That's",'funny']
    assert(words==toWords(s))
    
    s = "For only $10"
    words = ['For','only','$','10']
    assert(words==toWords(s))
    
testToWords()
print("test passed")
# Out:
# test passed

# %% [markdown]
# ## utilities

# %%
def capitalise(word):
    if len(word) == 1:
        return(word.upper())
    else:
        return(word[0].upper() + word[1:])

assert(capitalise('a') == 'A')
assert(capitalise('hello') == 'Hello')
assert(capitalise('A') == 'A')
assert(capitalise('Hello') == 'Hello')

def filter(word):
    names = ['Ben','James','Tyson','Steve','Andrew',
             'Campbell','Jen','Margaret','Nigel', 
             'Kim','James-Paul','Gary','Kym','Rob','Stu',
             'Stuart','David','Cynthea','Zema','Jock','Sam',
             'Bill','Claudia','Clive','Otto','Kate','Morgan','Ash'
            ]
    for name in names:
        if word in [name,name + "'s",name + "’s"]:
            return(True)
    if word.lower() in ['angel',"angel's","angels",'naked','his']:
        # Naked Wines mentions these a lot
        return(True)
    elif word.lower() in ['points']:
        # wineonline mentions these
        return(True)
    else:
        return(False)
    
def applyFilter(k):
    if type(k) == '':
        return(filter(k))
    elif type(k) == type(('','')):
        return any([filter(w) for w in words])
    else:
        assert(False)
    
# data is a dictionary
# the keys are what we are choosing
# the values are the weights
def weightedRandom(dist):
    
    entries = [k for k in dist.keys()]
    if len(entries) == 0:
        return(None) # all filtered out
    probabilities = [dist[e] for e in entries]
    scale = sum(probabilities)
    probabilities = [float(p)/scale for p in probabilities]
    draw = choice(range(len(entries)), 1, p=probabilities)[0]
    return(entries[draw])

# takes in a word (string with no whitespace)
# If that is a positive integer, returns a generalised string
# so that '1' and '3' map to the same value
# which makes my markov chain more generalised
def generaliseNum(word):
    word
    # return non-number strings as they are
    if word in ['','.','0',',']:
        return(word)
    elif not all([c in '1234567890,' for c in word]):
        return(word)
    
    try:
        x = int(word.replace(',',''))
    except ValueError as e:
        print("Word: %s" % word)
        raise(e)
    assert(x > 0)
    
    if x <= 10:
        return('MAGIC_INT_ONE_TO_TEN')
    elif x <= 100:
        return('MAGIC_INT_LESS_THAN_HUNDRED')
    elif x < 1900:
        return("MAGIC_INT_THOUSANDS")
    elif 1900 < x <= 2020:
        return('MAGIC_INT_YEAR')
    elif x < 10000:
        return("MAGIC_INT_TEN_THOUSANDS")
    else:
        return(word)
       
# undo generaliseNum
# not exactly, since it will come out with a different number, but same range
def ungeneraliseNum(word):
    word = str(word) 
    if not word.startswith('MAGIC'):
        return(word)
    elif word == 'MAGIC_INT_ONE_TO_TEN':
        return(str(randint(1,10)))
    elif word == 'MAGIC_INT_LESS_THAN_HUNDRED':
        return(str(randint(11,99)))
    elif word == "MAGIC_INT_THOUSANDS":
        return(str(randint(101,1900)))
    elif word == 'MAGIC_INT_YEAR':
        return(str(randint(1900,2020)))
    elif word == "MAGIC_INT_TEN_THOUSANDS":
        return(str(randint(2020,10000)))
    else:
        return(word)
        
for x in [0,1,3,10,12,50,99,100,1300,1901,2010,10000,'asd',-1]:
    start = str(x)
    middle = generaliseNum(start)
    end = ungeneraliseNum(middle)
    print('%s -> %s -> %s' % (start,middle,end))

    
assert(generaliseNum("1,001") == 'MAGIC_INT_THOUSANDS')
# Out:
# 0 -> 0 -> 0
# 1 -> MAGIC_INT_ONE_TO_TEN -> 1
# 3 -> MAGIC_INT_ONE_TO_TEN -> 8
# 10 -> MAGIC_INT_ONE_TO_TEN -> 10
# 12 -> MAGIC_INT_LESS_THAN_HUNDRED -> 68
# 50 -> MAGIC_INT_LESS_THAN_HUNDRED -> 95
# 99 -> MAGIC_INT_LESS_THAN_HUNDRED -> 64
# 100 -> MAGIC_INT_LESS_THAN_HUNDRED -> 26
# 1300 -> MAGIC_INT_THOUSANDS -> 713
# 1901 -> MAGIC_INT_YEAR -> 1925
# 2010 -> MAGIC_INT_YEAR -> 1926
# 10000 -> 10000 -> 10000
# asd -> asd -> asd
# -1 -> -1 -> -1

# %% [markdown]
# # N Layer chain

# %%
numLayers = 5
assert(numLayers > 0)

# %%
for x in range(100):
    for endChar in [' .!?;)`\'"']:
        for startChar in [' \n(`"\'']:
            for toCapitalise in [True,False]:
                if toCapitalise:
                    searchFor = startChar + capitalise(num2words(x)) + endChar
                else:
                    searchFor = startChar + num2words(x) + endChar
                replace = startChar + str(x) + endChar
                allText = allText.replace(searchFor,replace)
print("done")
# Out:
# done

# %%
allText = allText.replace('mouthfeel','mouth-feel').replace('mouth feel','mouth-feel') # make them the same
allTextSplit = toWords(allText)
#print(allTextSplit)

# %%
words = [generaliseNum(w) for w in allTextSplit]
words = [('and' if w  == '&' else w) for w in words]
words = [('.' if w  == '.' else w) for w in words]

# split allTextSplit into a list of sentences, where each sentence is a list of words
sentences = [[]]
for word in words:
    sentences[-1].append(word)
    if word in '?!.':
        sentences.append([])

# %%
dataStart = {}
data = {N:{} for N in range(1,numLayers+1)}

solo = 0
many = 0

for sentence in sentences:
    if len(sentence) > numLayers:
        # get the start of the sentence
        firstN = tuple(sentence[0:numLayers])
        if (not any([filter(w) for w in firstN])) and (firstN[0] not in '-.;!?'): # filter start tuple
            if firstN in dataStart:
                dataStart[firstN] += 1
            else:
                dataStart[firstN] = 1

        for N in range(1,numLayers+1):
            # now the rest
            for i in range(N,len(sentence)):
                thisWord = sentence[i]
                prevWords = tuple(sentence[i-N:i])
                if not filter(thisWord):
                    if prevWords not in data[N]:
                        data[N][prevWords] = {thisWord:1}
                    elif thisWord not in data[N][prevWords]:
                        data[N][prevWords][thisWord] = 1
                        solo += 1
                    else:
                        data[N][prevWords][thisWord] += 1
                        many += 1

    
print("solo: %d" % solo)
print("many: %d" % many)
# Out:
# solo: 46995
# many: 70527

# %%
# returns True p of the time
# e.g. p=0.5 is a coin flip
# p == 1 is always true
def coinFlip(p):
    return(random.random() < p)

# %%
def generateSentenceMany():
#     print("generating sentence")
    words = list(weightedRandom(dataStart))
#     print("First %d words are: %s" % (numLayers,str(words)))
    stats = {x:0 for x in range(1,numLayers+1)}
    numOnlyChoice = 0 # number of words where that is the only valid next choice
    while words[-1] not in '!?.':
        
        # try to find the next work
        nextWord = None
        for N in range(numLayers,1-1,-1): # from numLayers to 1
#             print("N=%d words=%s" % (N,str(words)))
            prevWords = tuple(words[-N:])
            assert(type(prevWords) == type((1,2)))
            if prevWords in data[N]:
                weights = data[N][prevWords]
                nextWord = weightedRandom(weights) # returns None if all possibilities are filtered
                if nextWord != None:
                    if (N != 1) and (len(weights) == 1):
                        # if there's only one option, flip a coin
                        # this is because I don't want to copy and paste whole phrases from the dataset
                        if coinFlip(1/N):
                            numOnlyChoice += 1
                            break
                        else:
                            nextWord = None
                    else:
                        if (len(weights) == 1) and (sum([weights[w] for w in weights]) == 1):
                            numOnlyChoice += 1
                        break
        try:
            assert(nextWord)
        except AssertionError as e:
            print("words: ")
            print(words)
            print("%s in data[%d] = %s" % (words[-1],1,(words[-1],) in data[1]))
            raise(e)
        try:
            assert(type(nextWord) == type(''))
        except AssertionError as e:
            print("nextWord: " + str(nextWord))
            raise(e)
        stats[N] += 1
#         print("appending word")
        words.append(nextWord)
    
    if numOnlyChoice > 0.8 * len(words):
        print("Discarding because too many only choice: " + str(words))
        return(generateSentenceMany())
    
    stats['numOnly'] = numOnlyChoice
    stats['numMany'] = len(words) - numOnlyChoice
    
    words = [ungeneraliseNum(w) for w in words]
        
    sentence = capitalise(words[0])
    for word in words[1:]:
        if (word not in ',.!?;%') and (word != '...') and (sentence[-1] != '$'):
            sentence += ' '
        sentence += word
        
    if not (5 < len(sentence.split(' ')) < 25):
        # bad length, try again
        return(generateSentenceMany())
    else:
        return({'sentence':sentence,'stats':stats})

for _ in range(20):
    result = generateSentenceMany()
    print(result['sentence'])
    print(result['stats'])
    print('')
# Out:
# Get ready for aromas of pears, green apples, citrus, and a luxurious loooong finish.
# {1: 2, 2: 0, 3: 8, 4: 1, 5: 2, 'numOnly': 6, 'numMany': 12}
#
# This is a serious cabernet without the serious, Odyssey cabernet sauvignon with well integrated cedary oak laid over subtle red and blueberries.
# {1: 3, 2: 9, 3: 3, 4: 3, 5: 1, 'numOnly': 10, 'numMany': 14}
#
# Rich, ripe and a deliciously long finish!
# {1: 0, 2: 0, 3: 2, 4: 1, 5: 1, 'numOnly': 3, 'numMany': 6}
#
# It broadcasts intense flavours of dark forest berries, cherries and savoury notes introduce you to your happy place!
# {1: 1, 2: 3, 3: 6, 4: 2, 5: 3, 'numOnly': 7, 'numMany': 13}
#
# It's light mouth-feel is softly textured and smooth, with lots of mid palate with cranberrylike acidity and subtle spice.
# {1: 2, 2: 5, 3: 3, 4: 3, 5: 3, 'numOnly': 9, 'numMany': 12}
#
# This ripping shiraz comes from 47 year.
# {1: 1, 2: 0, 3: 0, 4: 2, 5: 0, 'numOnly': 2, 'numMany': 6}
#
# Mitchelton shiraz is an opulent, melted and supple style leaving a sensation of fullness.
# {1: 0, 2: 2, 3: 5, 4: 1, 5: 3, 'numOnly': 10, 'numMany': 6}
#
# Dive in to the wonderful clarity and nutrients are spread the love!
# {1: 3, 2: 3, 3: 1, 4: 0, 5: 1, 'numOnly': 3, 'numMany': 10}
#
# Aromas of fragrant white peach all the way through to apricot will deliver aromas of green apple and a touch of flint.
# {1: 1, 2: 4, 3: 6, 4: 3, 5: 4, 'numOnly': 10, 'numMany': 13}
#
# Notes of sun-dried tomatoes, your favourite red hues, you'll be treated to aromas of plums, toffee.
# {1: 4, 2: 5, 3: 2, 4: 1, 5: 3, 'numOnly': 5, 'numMany': 15}
#
# With a cellaring potential of grapes.
# {1: 0, 2: 2, 3: 0, 4: 0, 5: 0, 'numOnly': 0, 'numMany': 7}
#
# The palate is layered and finely-textured, with ripe gooseberry, tropical and citrus notes, exotic and refreshing… and sure to be a knockout!
# {1: 1, 2: 3, 3: 9, 4: 7, 5: 1, 'numOnly': 12, 'numMany': 14}
#
# The natural fruit sweetness is balanced with a lingering crunchy acidity that continues to keep you guessing and reaching for another glass!
# {1: 0, 2: 3, 3: 8, 4: 5, 5: 2, 'numOnly': 12, 'numMany': 11}
#
# Rich, ripe and a deliciously long finish!
# {1: 0, 2: 2, 3: 0, 4: 0, 5: 2, 'numOnly': 3, 'numMany': 6}
#
# Widowed at the tender age of this wine.
# {1: 0, 2: 1, 3: 2, 4: 0, 5: 1, 'numOnly': 2, 'numMany': 7}
#
# Roses, wild strawberries, raspberry and plums.
# {1: 0, 2: 1, 3: 1, 4: 1, 5: 1, 'numOnly': 2, 'numMany': 7}
#
# It throws an amazing array of aromas out of WA.
# {1: 0, 2: 3, 3: 1, 4: 0, 5: 2, 'numOnly': 3, 'numMany': 8}
#
# The wine exhibits intense flavours and a subtle spice that lasts and lasts… pick that chin up off the floor!
# {1: 1, 2: 5, 3: 5, 4: 2, 5: 3, 'numOnly': 10, 'numMany': 11}
#
# This complex union of fruit tannin.
# {1: 0, 2: 2, 3: 0, 4: 0, 5: 0, 'numOnly': 0, 'numMany': 7}
#
# Rich and juicy red berry and dark cherry fruit, each sip is styled with fine melon and a hint of wild honey.
# {1: 1, 2: 4, 3: 4, 4: 7, 5: 3, 'numOnly': 10, 'numMany': 14}

# %% [markdown]
# # from a library

# %%
from ia_markov import MarkovModel

# %%
m = MarkovModel()

# %%
[x for x in dir(m) if not x.startswith('_')]
# Out:
# ['archive_name',
#  'exclude',
#  'make_sentence',
#  'model',
#  'sentence_split',
#  'state_size',
#  'train_model']

# %%
m._create_markov(allText)

# %%
print('\n\n'.join([m.make_sentence() for _ in range(10)]))
# Out:
# This wine offers a gentle textured palate, delicious depth of McLaren ‘terroir’.
#
# Ninth Island Chardonnay 2013 Brilliant very pale straw colour with aromas of pure lemon and lime flower aromas driving through to the finish.
#
# Do yourself a favour and enjoy all that's on offer from this region would normally sell for over 12 months in small quantities, so if you have guests!
#
# This wine is stored.
#
# The latest release of our Nebbiolo - a French word that refers to a sustainable approach.
#
# ” 93/100 Also listed among the best fruit made it possible.
#
# All grapes were picked, foot-crushed, hand-plunged and basket pressed then matured in both the Wairau and Awatere Valleys, the Smalls have chosen to blend Pinot Gris lovers, and always leave you wanting more.
#
# The gorgeous oaky notes of all this, each sip is full-bodied with taut acidity and subtle oak.
#
# The varietal is finding huge favour in Australia and the Lower Wairau grapes gift the palate will be treated with approachable plum and dark cherry with wisps of nutmeg spice with a perfect starter for an old school about this wine is lively and fresh fruits that McLaren Vale shiraz, and has lithe and captivating.
#
# Over the years, so get in quick!
